# %%
! unzip /content/gtzan_dataset-20250401T215714Z-001.zip
# Out:
# Archive:  /content/gtzan_dataset-20250401T215714Z-001.zip
#   inflating: gtzan_dataset/images_original/blues/blues00092.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00093.wav
#   inflating: gtzan_dataset/images_original/blues/blues00088.png
#   inflating: gtzan_dataset/images_original/blues/blues00085.png
#   inflating: gtzan_dataset/images_original/blues/blues00087.png
#   inflating: gtzan_dataset/images_original/blues/blues00097.png
#   inflating: gtzan_dataset/images_original/blues/blues00083.png
#   inflating: gtzan_dataset/images_original/blues/blues00091.png
#   inflating: gtzan_dataset/images_original/blues/blues00096.png
#   inflating: gtzan_dataset/images_original/blues/blues00090.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00080.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00094.wav
#   inflating: gtzan_dataset/features_30_sec.csv
#   inflating: gtzan_dataset/images_original/blues/blues00065.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00095.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00099.wav
#   inflating: gtzan_dataset/images_original/blues/blues00098.png
#   inflating: gtzan_dataset/images_original/blues/blues00086.png
#   inflating: gtzan_dataset/images_original/blues/blues00099.png
#   inflating: gtzan_dataset/images_original/blues/blues00081.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00097.wav
#   inflating: gtzan_dataset/images_original/blues/blues00082.png
#   inflating: gtzan_dataset/images_original/blues/blues00084.png
#   inflating: gtzan_dataset/images_original/blues/blues00095.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00098.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00088.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00084.wav
#   inflating: gtzan_dataset/images_original/blues/blues00094.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00096.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00091.wav
#   inflating: gtzan_dataset/images_original/blues/blues00041.png
#   inflating: gtzan_dataset/images_original/blues/blues00079.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00092.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00089.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00082.wav
#   inflating: gtzan_dataset/images_original/blues/blues00066.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00087.wav
#   inflating: gtzan_dataset/images_original/blues/blues00073.png
#   inflating: gtzan_dataset/images_original/blues/blues00048.png
#   inflating: gtzan_dataset/images_original/blues/blues00069.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00085.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00079.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00074.wav
#   inflating: gtzan_dataset/images_original/blues/blues00047.png
#   inflating: gtzan_dataset/images_original/blues/blues00080.png
#   inflating: gtzan_dataset/images_original/blues/blues00051.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00086.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00081.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00051.wav
#   inflating: gtzan_dataset/images_original/blues/blues00060.png
#   inflating: gtzan_dataset/images_original/blues/blues00061.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00076.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00083.wav
#   inflating: gtzan_dataset/images_original/blues/blues00062.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00078.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00064.wav
#   inflating: gtzan_dataset/images_original/blues/blues00070.png
#   inflating: gtzan_dataset/images_original/blues/blues00072.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00063.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00090.wav
#   inflating: gtzan_dataset/images_original/blues/blues00078.png
#   inflating: gtzan_dataset/images_original/blues/blues00050.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00065.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00073.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00066.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00068.wav
#   inflating: gtzan_dataset/images_original/blues/blues00071.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00075.wav
#   inflating: gtzan_dataset/images_original/blues/blues00057.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00077.wav
#   inflating: gtzan_dataset/images_original/blues/blues00040.png
#   inflating: gtzan_dataset/images_original/blues/blues00093.png
#   inflating: gtzan_dataset/images_original/blues/blues00076.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00070.wav
#   inflating: gtzan_dataset/images_original/blues/blues00044.png
#   inflating: gtzan_dataset/images_original/blues/blues00052.png
#   inflating: gtzan_dataset/images_original/blues/blues00043.png
#   inflating: gtzan_dataset/images_original/blues/blues00074.png
#   inflating: gtzan_dataset/images_original/blues/blues00075.png
#   inflating: gtzan_dataset/images_original/blues/blues00056.png
#   inflating: gtzan_dataset/images_original/blues/blues00045.png
#   inflating: gtzan_dataset/images_original/blues/blues00053.png
#   inflating: gtzan_dataset/images_original/blues/blues00046.png
#   inflating: gtzan_dataset/images_original/blues/blues00067.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00056.wav
#   inflating: gtzan_dataset/images_original/blues/blues00055.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00057.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00055.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00058.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00072.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00060.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00059.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00054.wav
#   inflating: gtzan_dataset/images_original/blues/blues00058.png
#   inflating: gtzan_dataset/images_original/blues/blues00018.png
#   inflating: gtzan_dataset/features_3_sec.csv
#   inflating: gtzan_dataset/images_original/blues/blues00064.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00035.wav
#   inflating: gtzan_dataset/images_original/blues/blues00059.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00052.wav
#   inflating: gtzan_dataset/images_original/blues/blues00068.png
#   inflating: gtzan_dataset/images_original/blues/blues00089.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00069.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00071.wav
#   inflating: gtzan_dataset/images_original/blues/blues00063.png
#   inflating: gtzan_dataset/images_original/blues/blues00054.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00067.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00046.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00062.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00048.wav
#   inflating: gtzan_dataset/images_original/blues/blues00049.png
#   inflating: gtzan_dataset/images_original/blues/blues00015.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00031.wav
#   inflating: gtzan_dataset/images_original/blues/blues00010.png
#   inflating: gtzan_dataset/images_original/blues/blues00077.png
#   inflating: gtzan_dataset/images_original/blues/blues00027.png
#   inflating: gtzan_dataset/images_original/blues/blues00038.png
#   inflating: gtzan_dataset/images_original/blues/blues00006.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00040.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00033.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00053.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00049.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00041.wav
#   inflating: gtzan_dataset/images_original/blues/blues00033.png
#   inflating: gtzan_dataset/images_original/blues/blues00002.png
#   inflating: gtzan_dataset/images_original/blues/blues00037.png
#   inflating: gtzan_dataset/images_original/blues/blues00011.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00047.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00043.wav
#   inflating: gtzan_dataset/images_original/blues/blues00031.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00030.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00050.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00034.wav
#   inflating: gtzan_dataset/images_original/blues/blues00007.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00044.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00088.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00025.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00036.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00094.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00097.wav
#   inflating: gtzan_dataset/images_original/blues/blues00017.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00023.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00013.wav
#   inflating: gtzan_dataset/images_original/blues/blues00022.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00015.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00042.wav
#   inflating: gtzan_dataset/images_original/blues/blues00042.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00089.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00098.wav
#   inflating: gtzan_dataset/images_original/blues/blues00019.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00038.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00093.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00019.wav
#   inflating: gtzan_dataset/images_original/blues/blues00025.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00090.wav
#   inflating: gtzan_dataset/images_original/blues/blues00014.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00092.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00032.wav
#   inflating: gtzan_dataset/images_original/blues/blues00000.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00012.wav
#   inflating: gtzan_dataset/images_original/blues/blues00035.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00037.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00045.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00091.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00099.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00027.wav
#   inflating: gtzan_dataset/images_original/blues/blues00016.png
#   inflating: gtzan_dataset/images_original/blues/blues00026.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00083.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00039.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00022.wav
#   inflating: gtzan_dataset/images_original/blues/blues00005.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00018.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00074.wav
#   inflating: gtzan_dataset/images_original/blues/blues00009.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00075.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00086.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00017.wav
#   inflating: gtzan_dataset/images_original/blues/blues00003.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00029.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00009.wav
#   inflating: gtzan_dataset/images_original/blues/blues00036.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00095.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00024.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00014.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00028.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00073.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00076.wav
#   inflating: gtzan_dataset/images_original/blues/blues00028.png
#   inflating: gtzan_dataset/images_original/blues/blues00021.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00026.wav
#   inflating: gtzan_dataset/images_original/blues/blues00004.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00077.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00096.wav
#   inflating: gtzan_dataset/images_original/blues/blues00008.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00001.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00080.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00021.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00007.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00010.wav
#   inflating: gtzan_dataset/images_original/blues/blues00001.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00016.wav
#   inflating: gtzan_dataset/images_original/blues/blues00034.png
#   inflating: gtzan_dataset/images_original/blues/blues00020.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00005.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00068.wav
#   inflating: gtzan_dataset/images_original/blues/blues00024.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00008.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00011.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00081.wav
#   inflating: gtzan_dataset/images_original/blues/blues00032.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00020.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00069.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00087.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00000.wav
#   inflating: gtzan_dataset/images_original/blues/blues00013.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00070.wav
#   inflating: gtzan_dataset/images_original/blues/blues00012.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00004.wav
#   inflating: gtzan_dataset/images_original/blues/blues00023.png
#   inflating: gtzan_dataset/images_original/blues/blues00030.png
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00006.wav
#   inflating: gtzan_dataset/images_original/blues/blues00029.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00078.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00067.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00085.wav
#   inflating: gtzan_dataset/images_original/blues/blues00039.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00072.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00071.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00061.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00053.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00003.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00082.wav
#   inflating: gtzan_dataset/images_original/country/country00088.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00046.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00065.wav
#   inflating: gtzan_dataset/images_original/country/country00072.png
#   inflating: gtzan_dataset/images_original/country/country00080.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00057.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00079.wav
#   inflating: gtzan_dataset/images_original/country/country00096.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00054.wav
#   inflating: gtzan_dataset/images_original/country/country00073.png
#   inflating: gtzan_dataset/images_original/country/country00086.png
#   inflating: gtzan_dataset/images_original/country/country00064.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00059.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00064.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00062.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00084.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00048.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00047.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00055.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00060.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00063.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00066.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00039.wav
#   inflating: gtzan_dataset/genres_original/hiphop/hiphop.00002.wav
#   inflating: gtzan_dataset/images_original/country/country00062.png
#   inflating: gtzan_dataset/images_original/country/country00099.png
#   inflating: gtzan_dataset/images_original/country/country00060.png
#   inflating: gtzan_dataset/images_original/country/country00071.png
#   inflating: gtzan_dataset/images_original/country/country00061.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00051.wav
#   inflating: gtzan_dataset/images_original/country/country00069.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00038.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00049.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00050.wav
#   inflating: gtzan_dataset/images_original/country/country00083.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00052.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00056.wav
#   inflating: gtzan_dataset/images_original/country/country00068.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00058.wav
#   inflating: gtzan_dataset/images_original/country/country00077.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00043.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00042.wav
#   inflating: gtzan_dataset/images_original/country/country00085.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00036.wav
#   inflating: gtzan_dataset/genres_original/country/country.00084.wav
#   inflating: gtzan_dataset/images_original/country/country00055.png
#   inflating: gtzan_dataset/images_original/country/country00093.png
#   inflating: gtzan_dataset/genres_original/country/country.00085.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00044.wav
#   inflating: gtzan_dataset/images_original/country/country00094.png
#   inflating: gtzan_dataset/images_original/country/country00087.png
#   inflating: gtzan_dataset/genres_original/country/country.00087.wav
#   inflating: gtzan_dataset/genres_original/country/country.00091.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00029.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00041.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00040.wav
#   inflating: gtzan_dataset/images_original/country/country00076.png
#   inflating: gtzan_dataset/images_original/country/country00070.png
#   inflating: gtzan_dataset/images_original/country/country00089.png
#   inflating: gtzan_dataset/genres_original/country/country.00083.wav
#   inflating: gtzan_dataset/genres_original/country/country.00097.wav
#   inflating: gtzan_dataset/genres_original/country/country.00093.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00034.wav
#   inflating: gtzan_dataset/images_original/country/country00057.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00037.wav
#   inflating: gtzan_dataset/genres_original/country/country.00092.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00032.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00028.wav
#   inflating: gtzan_dataset/images_original/country/country00092.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00033.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00025.wav
#   inflating: gtzan_dataset/images_original/country/country00056.png
#   inflating: gtzan_dataset/genres_original/country/country.00099.wav
#   inflating: gtzan_dataset/genres_original/country/country.00094.wav
#   inflating: gtzan_dataset/genres_original/country/country.00089.wav
#   inflating: gtzan_dataset/genres_original/country/country.00067.wav
#   inflating: gtzan_dataset/images_original/country/country00063.png
#   inflating: gtzan_dataset/genres_original/country/country.00096.wav
#   inflating: gtzan_dataset/images_original/country/country00059.png
#   inflating: gtzan_dataset/images_original/country/country00065.png
#   inflating: gtzan_dataset/genres_original/country/country.00086.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00035.wav
#   inflating: gtzan_dataset/genres_original/country/country.00079.wav
#   inflating: gtzan_dataset/images_original/country/country00078.png
#   inflating: gtzan_dataset/images_original/country/country00075.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00024.wav
#   inflating: gtzan_dataset/images_original/country/country00081.png
#   inflating: gtzan_dataset/genres_original/country/country.00074.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00013.wav
#   inflating: gtzan_dataset/genres_original/country/country.00088.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00031.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00023.wav
#   inflating: gtzan_dataset/genres_original/country/country.00098.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00045.wav
#   inflating: gtzan_dataset/images_original/country/country00084.png
#   inflating: gtzan_dataset/genres_original/country/country.00066.wav
#   inflating: gtzan_dataset/images_original/country/country00066.png
#   inflating: gtzan_dataset/images_original/country/country00074.png
#   inflating: gtzan_dataset/images_original/country/country00090.png
#   inflating: gtzan_dataset/genres_original/country/country.00082.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00026.wav
#   inflating: gtzan_dataset/genres_original/country/country.00095.wav
#   inflating: gtzan_dataset/genres_original/country/country.00068.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00030.wav
#   inflating: gtzan_dataset/images_original/country/country00098.png
#   inflating: gtzan_dataset/genres_original/country/country.00061.wav
#   inflating: gtzan_dataset/genres_original/country/country.00063.wav
#   inflating: gtzan_dataset/images_original/country/country00095.png
#   inflating: gtzan_dataset/genres_original/country/country.00064.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00009.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00027.wav
#   inflating: gtzan_dataset/genres_original/country/country.00060.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00022.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00008.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00005.wav
#   inflating: gtzan_dataset/genres_original/country/country.00072.wav
#   inflating: gtzan_dataset/images_original/country/country00067.png
#   inflating: gtzan_dataset/genres_original/country/country.00076.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00002.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00018.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00003.wav
#   inflating: gtzan_dataset/genres_original/country/country.00090.wav
#   inflating: gtzan_dataset/images_original/country/country00058.png
#   inflating: gtzan_dataset/genres_original/country/country.00069.wav
#   inflating: gtzan_dataset/images_original/country/country00079.png
#   inflating: gtzan_dataset/images_original/country/country00024.png
#   inflating: gtzan_dataset/genres_original/country/country.00062.wav
#   inflating: gtzan_dataset/genres_original/country/country.00080.wav
#   inflating: gtzan_dataset/genres_original/country/country.00071.wav
#   inflating: gtzan_dataset/images_original/country/country00091.png
#   inflating: gtzan_dataset/genres_original/country/country.00070.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00007.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00004.wav
#   inflating: gtzan_dataset/genres_original/country/country.00075.wav
#   inflating: gtzan_dataset/images_original/country/country00082.png
#   inflating: gtzan_dataset/images_original/country/country00016.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00016.wav
#   inflating: gtzan_dataset/genres_original/country/country.00077.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00012.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00021.wav
#   inflating: gtzan_dataset/genres_original/country/country.00073.wav
#   inflating: gtzan_dataset/genres_original/country/country.00081.wav
#   inflating: gtzan_dataset/images_original/pop/pop00099.png
#   inflating: gtzan_dataset/genres_original/country/country.00065.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00014.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00015.wav
#   inflating: gtzan_dataset/images_original/country/country00097.png
#   inflating: gtzan_dataset/genres_original/country/country.00078.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00020.wav
#   inflating: gtzan_dataset/images_original/country/country00013.png
#   inflating: gtzan_dataset/images_original/country/country00054.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00006.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00010.wav
#   inflating: gtzan_dataset/images_original/country/country00035.png
#   inflating: gtzan_dataset/images_original/pop/pop00095.png
#   inflating: gtzan_dataset/images_original/country/country00038.png
#   inflating: gtzan_dataset/images_original/country/country00034.png
#   inflating: gtzan_dataset/genres_original/country/country.00056.wav
#   inflating: gtzan_dataset/images_original/pop/pop00098.png
#   inflating: gtzan_dataset/genres_original/country/country.00055.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00017.wav
#   inflating: gtzan_dataset/images_original/country/country00026.png
#   inflating: gtzan_dataset/images_original/pop/pop00092.png
#   inflating: gtzan_dataset/genres_original/country/country.00049.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00083.png
#   inflating: gtzan_dataset/genres_original/country/country.00054.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00019.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00067.png
#   inflating: gtzan_dataset/genres_original/disco/disco.00011.wav
#   inflating: gtzan_dataset/images_original/country/country00018.png
#   inflating: gtzan_dataset/images_original/country/country00046.png
#   inflating: gtzan_dataset/genres_original/country/country.00051.wav
#   inflating: gtzan_dataset/images_original/pop/pop00094.png
#   inflating: gtzan_dataset/genres_original/country/country.00043.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00001.wav
#   inflating: gtzan_dataset/images_original/country/country00049.png
#   inflating: gtzan_dataset/images_original/country/country00030.png
#   inflating: gtzan_dataset/images_original/country/country00040.png
#   inflating: gtzan_dataset/genres_original/country/country.00052.wav
#   inflating: gtzan_dataset/genres_original/disco/disco.00000.wav
#   inflating: gtzan_dataset/genres_original/country/country.00057.wav
#   inflating: gtzan_dataset/images_original/country/country00036.png
#   inflating: gtzan_dataset/genres_original/country/country.00046.wav
#   inflating: gtzan_dataset/images_original/pop/pop00090.png
#   inflating: gtzan_dataset/images_original/pop/pop00053.png
#   inflating: gtzan_dataset/images_original/country/country00020.png
#   inflating: gtzan_dataset/genres_original/country/country.00050.wav
#   inflating: gtzan_dataset/images_original/rock/rock00068.png
#   inflating: gtzan_dataset/images_original/pop/pop00097.png
#   inflating: gtzan_dataset/genres_original/country/country.00042.wav
#   inflating: gtzan_dataset/images_original/rock/rock00072.png
#   inflating: gtzan_dataset/images_original/country/country00047.png
#   inflating: gtzan_dataset/images_original/country/country00037.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00090.png
#   inflating: gtzan_dataset/images_original/country/country00052.png
#   inflating: gtzan_dataset/images_original/pop/pop00056.png
#   inflating: gtzan_dataset/images_original/pop/pop00051.png
#   inflating: gtzan_dataset/images_original/pop/pop00085.png
#   inflating: gtzan_dataset/images_original/rock/rock00091.png
#   inflating: gtzan_dataset/images_original/pop/pop00047.png
#   inflating: gtzan_dataset/images_original/rock/rock00070.png
#   inflating: gtzan_dataset/genres_original/country/country.00039.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00099.png
#   inflating: gtzan_dataset/genres_original/country/country.00044.wav
#   inflating: gtzan_dataset/images_original/pop/pop00093.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00068.png
#   inflating: gtzan_dataset/genres_original/country/country.00048.wav
#   inflating: gtzan_dataset/images_original/rock/rock00090.png
#   inflating: gtzan_dataset/images_original/country/country00041.png
#   inflating: gtzan_dataset/genres_original/country/country.00045.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00096.png
#   inflating: gtzan_dataset/images_original/rock/rock00096.png
#   inflating: gtzan_dataset/images_original/country/country00022.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00094.png
#   inflating: gtzan_dataset/images_original/pop/pop00076.png
#   inflating: gtzan_dataset/images_original/rock/rock00099.png
#   inflating: gtzan_dataset/images_original/rock/rock00078.png
#   inflating: gtzan_dataset/images_original/pop/pop00048.png
#   inflating: gtzan_dataset/images_original/pop/pop00063.png
#   inflating: gtzan_dataset/images_original/pop/pop00070.png
#   inflating: gtzan_dataset/genres_original/country/country.00047.wav
#   inflating: gtzan_dataset/images_original/country/country00017.png
#   inflating: gtzan_dataset/images_original/rock/rock00098.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00074.png
#   inflating: gtzan_dataset/images_original/rock/rock00067.png
#   inflating: gtzan_dataset/images_original/country/country00019.png
#   inflating: gtzan_dataset/images_original/country/country00048.png
#   inflating: gtzan_dataset/images_original/rock/rock00075.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00081.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00098.png
#   inflating: gtzan_dataset/images_original/pop/pop00049.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00092.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00071.png
#   inflating: gtzan_dataset/images_original/rock/rock00094.png
#   inflating: gtzan_dataset/genres_original/country/country.00059.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00073.png
#   inflating: gtzan_dataset/images_original/country/country00053.png
#   inflating: gtzan_dataset/images_original/pop/pop00060.png
#   inflating: gtzan_dataset/images_original/country/country00028.png
#   inflating: gtzan_dataset/images_original/pop/pop00071.png
#   inflating: gtzan_dataset/images_original/pop/pop00072.png
#   inflating: gtzan_dataset/genres_original/country/country.00053.wav
#   inflating: gtzan_dataset/images_original/rock/rock00071.png
#   inflating: gtzan_dataset/images_original/country/country00015.png
#   inflating: gtzan_dataset/images_original/country/country00012.png
#   inflating: gtzan_dataset/images_original/rock/rock00097.png
#   inflating: gtzan_dataset/genres_original/country/country.00040.wav
#   inflating: gtzan_dataset/images_original/pop/pop00082.png
#   inflating: gtzan_dataset/images_original/rock/rock00093.png
#   inflating: gtzan_dataset/images_original/rock/rock00082.png
#   inflating: gtzan_dataset/images_original/country/country00025.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00069.png
#   inflating: gtzan_dataset/images_original/country/country00044.png
#   inflating: gtzan_dataset/genres_original/country/country.00022.wav
#   inflating: gtzan_dataset/genres_original/country/country.00058.wav
#   inflating: gtzan_dataset/images_original/pop/pop00061.png
#   inflating: gtzan_dataset/images_original/country/country00021.png
#   inflating: gtzan_dataset/genres_original/country/country.00041.wav
#   inflating: gtzan_dataset/images_original/rock/rock00074.png
#   inflating: gtzan_dataset/images_original/pop/pop00096.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00076.png
#   inflating: gtzan_dataset/images_original/pop/pop00054.png
#   inflating: gtzan_dataset/images_original/pop/pop00067.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00082.png
#   inflating: gtzan_dataset/images_original/rock/rock00080.png
#   inflating: gtzan_dataset/images_original/pop/pop00046.png
#   inflating: gtzan_dataset/images_original/pop/pop00057.png
#   inflating: gtzan_dataset/images_original/country/country00023.png
#   inflating: gtzan_dataset/images_original/pop/pop00055.png
#   inflating: gtzan_dataset/genres_original/country/country.00032.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00075.png
#   inflating: gtzan_dataset/images_original/rock/rock00077.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00095.png
#   inflating: gtzan_dataset/images_original/country/country00043.png
#   inflating: gtzan_dataset/images_original/rock/rock00086.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00093.png
#   inflating: gtzan_dataset/images_original/rock/rock00089.png
#   inflating: gtzan_dataset/images_original/country/country00045.png
#   inflating: gtzan_dataset/images_original/pop/pop00080.png
#   inflating: gtzan_dataset/genres_original/country/country.00028.wav
#   inflating: gtzan_dataset/images_original/country/country00014.png
#   inflating: gtzan_dataset/images_original/pop/pop00069.png
#   inflating: gtzan_dataset/genres_original/country/country.00030.wav
#   inflating: gtzan_dataset/images_original/country/country00027.png
#   inflating: gtzan_dataset/genres_original/country/country.00027.wav
#   inflating: gtzan_dataset/images_original/rock/rock00092.png
#   inflating: gtzan_dataset/images_original/rock/rock00079.png
#   inflating: gtzan_dataset/images_original/rock/rock00087.png
#   inflating: gtzan_dataset/images_original/rock/rock00081.png
#   inflating: gtzan_dataset/genres_original/country/country.00035.wav
#   inflating: gtzan_dataset/images_original/rock/rock00073.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00084.png
#   inflating: gtzan_dataset/images_original/country/country00042.png
#   inflating: gtzan_dataset/images_original/pop/pop00084.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00085.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00077.png
#   inflating: gtzan_dataset/images_original/country/country00033.png
#   inflating: gtzan_dataset/images_original/pop/pop00089.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00090.wav
#   inflating: gtzan_dataset/images_original/rock/rock00083.png
#   inflating: gtzan_dataset/images_original/country/country00039.png
#   inflating: gtzan_dataset/images_original/rock/rock00076.png
#   inflating: gtzan_dataset/images_original/country/country00032.png
#   inflating: gtzan_dataset/images_original/pop/pop00077.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00078.png
#   inflating: gtzan_dataset/images_original/pop/pop00086.png
#   inflating: gtzan_dataset/images_original/country/country00051.png
#   inflating: gtzan_dataset/images_original/pop/pop00050.png
#   inflating: gtzan_dataset/images_original/rock/rock00095.png
#   inflating: gtzan_dataset/genres_original/country/country.00034.wav
#   inflating: gtzan_dataset/images_original/pop/pop00058.png
#   inflating: gtzan_dataset/images_original/country/country00029.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00096.wav
#   inflating: gtzan_dataset/genres_original/pop/pop.00099.wav
#   inflating: gtzan_dataset/images_original/pop/pop00066.png
#   inflating: gtzan_dataset/images_original/pop/pop00081.png
#   inflating: gtzan_dataset/genres_original/country/country.00018.wav
#   inflating: gtzan_dataset/images_original/rock/rock00069.png
#   inflating: gtzan_dataset/images_original/rock/rock00084.png
#   inflating: gtzan_dataset/images_original/country/country00050.png
#   inflating: gtzan_dataset/genres_original/country/country.00031.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00079.png
#   inflating: gtzan_dataset/images_original/pop/pop00079.png
#   inflating: gtzan_dataset/images_original/country/country00031.png
#   inflating: gtzan_dataset/genres_original/country/country.00023.wav
#   inflating: gtzan_dataset/genres_original/pop/pop.00094.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00070.png
#   inflating: gtzan_dataset/images_original/rock/rock00036.png
#   inflating: gtzan_dataset/images_original/rock/rock00088.png
#   inflating: gtzan_dataset/images_original/rock/rock00037.png
#   inflating: gtzan_dataset/genres_original/country/country.00021.wav
#   inflating: gtzan_dataset/genres_original/pop/pop.00084.wav
#   inflating: gtzan_dataset/images_original/rock/rock00085.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00088.png
#   inflating: gtzan_dataset/images_original/country/country00002.png
#   inflating: gtzan_dataset/images_original/pop/pop00091.png
#   inflating: gtzan_dataset/images_original/country/country00007.png
#   inflating: gtzan_dataset/genres_original/country/country.00020.wav
#   inflating: gtzan_dataset/genres_original/country/country.00025.wav
#   inflating: gtzan_dataset/images_original/pop/pop00065.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00072.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00087.wav
#   inflating: gtzan_dataset/images_original/rock/rock00049.png
#   inflating: gtzan_dataset/images_original/country/country00004.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00091.png
#   inflating: gtzan_dataset/images_original/pop/pop00088.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00089.wav
#   inflating: gtzan_dataset/images_original/rock/rock00053.png
#   inflating: gtzan_dataset/genres_original/country/country.00038.wav
#   inflating: gtzan_dataset/images_original/country/country00001.png
#   inflating: gtzan_dataset/images_original/rock/rock00040.png
#   inflating: gtzan_dataset/images_original/pop/pop00087.png
#   inflating: gtzan_dataset/images_original/pop/pop00064.png
#   inflating: gtzan_dataset/genres_original/country/country.00036.wav
#   inflating: gtzan_dataset/images_original/pop/pop00052.png
#   inflating: gtzan_dataset/images_original/rock/rock00066.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00097.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00080.png
#   inflating: gtzan_dataset/images_original/rock/rock00038.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00088.wav
#   inflating: gtzan_dataset/genres_original/pop/pop.00097.wav
#   inflating: gtzan_dataset/genres_original/country/country.00033.wav
#   inflating: gtzan_dataset/genres_original/pop/pop.00098.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00066.png
#   inflating: gtzan_dataset/images_original/pop/pop00062.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00087.png
#   inflating: gtzan_dataset/images_original/country/country00010.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00086.png
#   inflating: gtzan_dataset/genres_original/country/country.00029.wav
#   inflating: gtzan_dataset/images_original/country/country00006.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00092.wav
#   inflating: gtzan_dataset/genres_original/country/country.00019.wav
#   inflating: gtzan_dataset/images_original/country/country00003.png
#   inflating: gtzan_dataset/images_original/rock/rock00024.png
#   inflating: gtzan_dataset/genres_original/country/country.00017.wav
#   inflating: gtzan_dataset/genres_original/pop/pop.00085.wav
#   inflating: gtzan_dataset/images_original/country/country00011.png
#   inflating: gtzan_dataset/images_original/rock/rock00056.png
#   inflating: gtzan_dataset/images_original/pop/pop00068.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00064.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00086.wav
#   inflating: gtzan_dataset/images_original/country/country00000.png
#   inflating: gtzan_dataset/images_original/pop/pop00059.png
#   inflating: gtzan_dataset/images_original/rock/rock00032.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00093.wav
#   inflating: gtzan_dataset/genres_original/pop/pop.00083.wav
#   inflating: gtzan_dataset/genres_original/pop/pop.00095.wav
#   inflating: gtzan_dataset/images_original/pop/pop00083.png
#   inflating: gtzan_dataset/images_original/country/country00009.png
#   inflating: gtzan_dataset/images_original/pop/pop00078.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00043.png
#   inflating: gtzan_dataset/images_original/rock/rock00051.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00082.wav
#   inflating: gtzan_dataset/images_original/rock/rock00029.png
#   inflating: gtzan_dataset/images_original/pop/pop00007.png
#   inflating: gtzan_dataset/images_original/pop/pop00075.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00091.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00050.png
#   inflating: gtzan_dataset/genres_original/country/country.00037.wav
#   inflating: gtzan_dataset/genres_original/country/country.00026.wav
#   inflating: gtzan_dataset/images_original/pop/pop00022.png
#   inflating: gtzan_dataset/images_original/country/country00005.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00089.png
#   inflating: gtzan_dataset/images_original/rock/rock00030.png
#   inflating: gtzan_dataset/images_original/rock/rock00058.png
#   inflating: gtzan_dataset/images_original/rock/rock00045.png
#   inflating: gtzan_dataset/genres_original/country/country.00004.wav
#   inflating: gtzan_dataset/images_original/pop/pop00074.png
#   inflating: gtzan_dataset/images_original/rock/rock00059.png
#   inflating: gtzan_dataset/images_original/rock/rock00035.png
#   inflating: gtzan_dataset/images_original/rock/rock00043.png
#   inflating: gtzan_dataset/images_original/rock/rock00050.png
#   inflating: gtzan_dataset/images_original/pop/pop00014.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00069.wav
#   inflating: gtzan_dataset/images_original/country/country00008.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00022.png
#   inflating: gtzan_dataset/images_original/pop/pop00073.png
#   inflating: gtzan_dataset/images_original/pop/pop00044.png
#   inflating: gtzan_dataset/images_original/pop/pop00035.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00073.wav
#   inflating: gtzan_dataset/images_original/rock/rock00031.png
#   inflating: gtzan_dataset/images_original/pop/pop00032.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00052.png
#   inflating: gtzan_dataset/images_original/pop/pop00028.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00047.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00061.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00020.png
#   inflating: gtzan_dataset/genres_original/country/country.00010.wav
#   inflating: gtzan_dataset/genres_original/pop/pop.00065.wav
#   inflating: gtzan_dataset/images_original/pop/pop00006.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00072.wav
#   inflating: gtzan_dataset/genres_original/country/country.00016.wav
#   inflating: gtzan_dataset/genres_original/country/country.00001.wav
#   inflating: gtzan_dataset/genres_original/pop/pop.00081.wav
#   inflating: gtzan_dataset/images_original/rock/rock00041.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00049.png
#   inflating: gtzan_dataset/genres_original/country/country.00024.wav
#   inflating: gtzan_dataset/images_original/pop/pop00031.png
#   inflating: gtzan_dataset/genres_original/country/country.00012.wav
#   inflating: gtzan_dataset/images_original/rock/rock00062.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00076.wav
#   inflating: gtzan_dataset/images_original/rock/rock00042.png
#   inflating: gtzan_dataset/images_original/rock/rock00027.png
#   inflating: gtzan_dataset/genres_original/country/country.00011.wav
#   inflating: gtzan_dataset/genres_original/pop/pop.00074.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00062.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00077.wav
#   inflating: gtzan_dataset/genres_original/country/country.00006.wav
#   inflating: gtzan_dataset/images_original/rock/rock00028.png
#   inflating: gtzan_dataset/images_original/rock/rock00064.png
#   inflating: gtzan_dataset/genres_original/country/country.00005.wav
#   inflating: gtzan_dataset/images_original/pop/pop00033.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00065.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00029.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00068.wav
#   inflating: gtzan_dataset/images_original/rock/rock00023.png
#   inflating: gtzan_dataset/images_original/pop/pop00013.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00027.png
#   inflating: gtzan_dataset/genres_original/country/country.00009.wav
#   inflating: gtzan_dataset/genres_original/country/country.00008.wav
#   inflating: gtzan_dataset/genres_original/pop/pop.00062.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00045.png
#   inflating: gtzan_dataset/images_original/rock/rock00063.png
#   inflating: gtzan_dataset/images_original/pop/pop00045.png
#   inflating: gtzan_dataset/images_original/pop/pop00010.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00040.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00078.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00055.png
#   inflating: gtzan_dataset/images_original/pop/pop00004.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00066.wav
#   inflating: gtzan_dataset/images_original/jazz/jazz00053.png
#   inflating: gtzan_dataset/images_original/rock/rock00047.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00031.png
#   inflating: gtzan_dataset/genres_original/country/country.00000.wav
#   inflating: gtzan_dataset/images_original/rock/rock00048.png
#   inflating: gtzan_dataset/genres_original/country/country.00014.wav
#   inflating: gtzan_dataset/genres_original/pop/pop.00064.wav
#   inflating: gtzan_dataset/genres_original/pop/pop.00070.wav
#   inflating: gtzan_dataset/images_original/pop/pop00021.png
#   inflating: gtzan_dataset/images_original/rock/rock00033.png
#   inflating: gtzan_dataset/images_original/jazz/jazz00046.png
#   inflating: gtzan_dataset/images_original/pop/pop00017.png
#   inflating: gtzan_dataset/genres_original/pop/pop.00063.wav
# ...
#   inflating: gtzan_dataset/genres_original/rock/rock.00086.wav
#   inflating: gtzan_dataset/images_original/hiphop/hiphop00023.png
#   inflating: gtzan_dataset/images_original/hiphop/hiphop00014.png
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00030.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00099.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00031.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00035.wav
#   inflating: gtzan_dataset/images_original/hiphop/hiphop00025.png
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00028.wav
#   inflating: gtzan_dataset/images_original/hiphop/hiphop00019.png
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00039.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00032.wav
#   inflating: gtzan_dataset/images_original/hiphop/hiphop00027.png
#   inflating: gtzan_dataset/genres_original/rock/rock.00093.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00044.wav
#   inflating: gtzan_dataset/images_original/hiphop/hiphop00018.png
#   inflating: gtzan_dataset/genres_original/rock/rock.00092.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00089.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00079.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00041.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00078.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00087.wav
#   inflating: gtzan_dataset/images_original/hiphop/hiphop00013.png
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00023.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00007.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00020.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00011.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00005.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00010.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00083.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00015.wav
#   inflating: gtzan_dataset/images_original/hiphop/hiphop00015.png
#   inflating: gtzan_dataset/genres_original/rock/rock.00081.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00088.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00012.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00016.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00021.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00017.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00097.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00019.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00082.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00096.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00009.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00006.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00085.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00018.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00055.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00036.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00014.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00080.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00061.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00040.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00062.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00004.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00067.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00090.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00091.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00065.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00094.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00024.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00076.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00002.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00022.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00070.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00095.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00074.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00084.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00060.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00087.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00093.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00008.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00073.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00001.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00066.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00059.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00064.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00090.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00089.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00097.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00000.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00088.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00072.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00092.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00096.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00095.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00068.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00056.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00071.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00069.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00073.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00013.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00053.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00086.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00064.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00042.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00091.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00063.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00035.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00057.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00044.wav
#   inflating: gtzan_dataset/genres_original/reggae/reggae.00003.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00075.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00054.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00065.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00058.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00050.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00079.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00074.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00039.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00068.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00075.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00049.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00043.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00045.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00052.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00066.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00081.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00072.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00041.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00098.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00080.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00048.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00036.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00077.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00082.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00046.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00078.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00099.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00033.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00071.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00034.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00069.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00014.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00070.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00051.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00038.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00047.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00050.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00047.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00058.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00018.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00076.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00040.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00051.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00016.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00037.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00084.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00030.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00015.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00013.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00083.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00020.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00057.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00024.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00046.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00026.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00019.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00067.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00044.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00017.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00062.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00049.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00054.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00032.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00028.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00029.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00063.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00045.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00048.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00043.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00021.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00040.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00031.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00042.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00012.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00023.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00085.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00052.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00022.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00011.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00005.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00027.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00031.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00056.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00004.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00041.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00003.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00006.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00061.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00025.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00009.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00018.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00036.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00055.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00001.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00060.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00019.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00025.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00020.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00010.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00034.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00022.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00000.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00024.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00038.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00030.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00059.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00002.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00021.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00014.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00026.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00039.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00000.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00028.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00008.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00029.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00037.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00008.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00035.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00027.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00007.wav
#   inflating: gtzan_dataset/genres_original/rock/rock.00007.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00032.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00009.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00033.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00023.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00053.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00003.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00017.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00005.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00002.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00006.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00001.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00010.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00012.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00004.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00011.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00013.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00015.wav
#   inflating: gtzan_dataset/genres_original/blues/blues.00016.wav

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchaudio
import torchaudio.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import librosa
import librosa.display
import numpy as np
import os
from glob import glob
import matplotlib.pyplot as plt

# Define constants
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SAMPLE_RATE = 22050
N_MELS = 128
N_FFT = 2048
HOP_LENGTH = 512
BATCH_SIZE = 8
EPOCHS = 50
LEARNING_RATE = 2e-4

# Load GTZAN dataset
class GTZANDataset(Dataset):
    def __init__(self, root_dir):
        self.file_paths = glob(os.path.join(root_dir, "genres_original", "*", "*.wav"))

        # Check if the dataset is empty
        if len(self.file_paths) == 0:
            raise ValueError(f"No .wav files found in {root_dir}/genres_original. Please check your dataset path.")

        self.labels = [os.path.basename(os.path.dirname(fp)) for fp in self.file_paths]
        self.label_dict = {genre: idx for idx, genre in enumerate(sorted(set(self.labels)))}

        self.transform = transforms.MelSpectrogram(
            sample_rate=SAMPLE_RATE,
            n_mels=N_MELS,
            n_fft=N_FFT,
            hop_length=HOP_LENGTH
        )

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        file_path = self.file_paths[idx]
        label = self.label_dict[self.labels[idx]]
        waveform, _ = librosa.load(file_path, sr=SAMPLE_RATE)
        waveform = torch.tensor(waveform[:SAMPLE_RATE*3])  # 3 seconds clip
        mel_spec = self.transform(waveform)  # Shape: [1, n_mels, time]
        return mel_spec.squeeze(0), label  # Return [n_mels, time]

# Load dataset
dataset_path = "/content/gtzan_dataset"
train_dataset = GTZANDataset(dataset_path)

# Print dataset size for debugging
print(f"Number of samples in dataset: {len(train_dataset)}")

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

# Define Transformer-based Generator
class TransformerGenerator(nn.Module):
    def __init__(self, input_dim=N_MELS, num_heads=4, ff_dim=256):
        super(TransformerGenerator, self).__init__()
        self.encoder_layer = nn.TransformerEncoderLayer(d_model=input_dim, nhead=num_heads, dim_feedforward=ff_dim)
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=6)
        self.fc = nn.Linear(input_dim, input_dim)

    def forward(self, x):
        x = x.permute(2, 0, 1)  # (batch, n_mels, time) -> (time, batch, n_mels)
        x = self.transformer_encoder(x)
        x = self.fc(x)
        x = x.permute(1, 2, 0)  # Back to (batch, n_mels, time)
        return x

# Define Discriminator
class CNNDiscriminator(nn.Module):
    def __init__(self, input_dim=N_MELS):
        super(CNNDiscriminator, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=(3, 3), stride=(2, 2), padding=1),
            nn.LeakyReLU(0.2),
            nn.Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),
            nn.Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = x.unsqueeze(1)  # Add channel dim: [batch, 1, n_mels, time]
        return self.conv(x)

# Define Genre Classifier
class GenreClassifier(nn.Module):
    def __init__(self, input_dim=N_MELS, num_classes=10):
        super(GenreClassifier, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.flattened_size = 128 * (N_MELS//8) * ((3*SAMPLE_RATE//HOP_LENGTH)//8)
        self.fc = nn.Sequential(
            nn.Linear(self.flattened_size, 256),
            nn.ReLU(),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = x.unsqueeze(1)  # Add channel dimension
        x = self.conv(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)

# Initialize models
generator = TransformerGenerator().to(device)
discriminator = CNNDiscriminator().to(device)
classifier = GenreClassifier().to(device)

##############################
# Training the Genre Classifier
##############################
print("Training the genre classifier...")
criterion = nn.CrossEntropyLoss()
classifier_optimizer = optim.Adam(classifier.parameters(), lr=1e-3)

best_classifier_loss = float('inf')

for epoch in range(50):
    epoch_loss = 0.0
    for mel_specs, labels in train_loader:
        mel_specs, labels = mel_specs.to(device), labels.to(device)

        classifier_optimizer.zero_grad()
        outputs = classifier(mel_specs)
        loss = criterion(outputs, labels)
        loss.backward()
        classifier_optimizer.step()

        epoch_loss += loss.item()

    epoch_loss /= len(train_loader)
    # Save the best classifier model
    if epoch_loss < best_classifier_loss:
        best_classifier_loss = epoch_loss
        torch.save(classifier.state_dict(), "best_genre_classifier.pth")
        print(f"Saved best classifier model at epoch {epoch+1} with loss {epoch_loss:.4f}")

    print(f"Classifier Epoch {epoch+1}, Average Loss: {epoch_loss:.4f}")

# Save the final classifier model (if needed)
torch.save(classifier.state_dict(), "genre_classifier.pth")
classifier.eval()

##############################
# Training the GAN
##############################
adversarial_loss = nn.BCELoss()
content_loss = nn.MSELoss()
cycle_loss = nn.L1Loss()

g_optimizer = optim.Adam(generator.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))
d_optimizer = optim.Adam(discriminator.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))

best_g_loss = float('inf')

print("Training the GAN...")
for epoch in range(EPOCHS):
    epoch_g_loss = 0.0
    for batch_idx, (real_data, _) in enumerate(train_loader):
        real_data = real_data.to(device)
        batch_size = real_data.size(0)

        # Generate fake data
        fake_data = generator(real_data)

        # Train Discriminator
        real_labels = torch.ones(batch_size, 1).to(device)
        fake_labels = torch.zeros(batch_size, 1).to(device)

        d_optimizer.zero_grad()
        real_output = discriminator(real_data)
        real_loss = adversarial_loss(real_output, real_labels)
        fake_output = discriminator(fake_data.detach())
        fake_loss = adversarial_loss(fake_output, fake_labels)
        d_loss = real_loss + fake_loss
        d_loss.backward()
        d_optimizer.step()

        # Train Generator
        g_optimizer.zero_grad()
        g_loss_adv = adversarial_loss(discriminator(fake_data), real_labels)
        g_loss_content = content_loss(fake_data, real_data)
        g_loss_cycle = cycle_loss(generator(fake_data), real_data)
        g_loss = g_loss_adv + 0.5 * g_loss_content + 0.5 * g_loss_cycle
        g_loss.backward()
        g_optimizer.step()

        epoch_g_loss += g_loss.item()

        if batch_idx % 10 == 0:
            print(f"GAN Epoch [{epoch+1}/{EPOCHS}] Batch [{batch_idx}/{len(train_loader)}] "
                  f"D Loss: {d_loss.item():.4f} G Loss: {g_loss.item():.4f}")

    epoch_g_loss /= len(train_loader)
    # Save the best generator model
    if epoch_g_loss < best_g_loss:
        best_g_loss = epoch_g_loss
        torch.save(generator.state_dict(), "best_generator.pth")
        print(f"Saved best generator model at epoch {epoch+1} with average G Loss {epoch_g_loss:.4f}")

    print(f"GAN Epoch [{epoch+1}/{EPOCHS}], Average Generator Loss: {epoch_g_loss:.4f}")

print("Training Complete!")
# Out:
# Number of samples in dataset: 998
# Training the genre classifier...
# Saved best classifier model at epoch 1 with loss 45.8812
# Classifier Epoch 1, Average Loss: 45.8812
# Saved best classifier model at epoch 2 with loss 2.2407
# Classifier Epoch 2, Average Loss: 2.2407
# Saved best classifier model at epoch 3 with loss 2.1084
# Classifier Epoch 3, Average Loss: 2.1084
# Saved best classifier model at epoch 4 with loss 1.9449
# Classifier Epoch 4, Average Loss: 1.9449
# Saved best classifier model at epoch 5 with loss 1.7649
# Classifier Epoch 5, Average Loss: 1.7649
# Saved best classifier model at epoch 6 with loss 1.5039
# Classifier Epoch 6, Average Loss: 1.5039
# Saved best classifier model at epoch 7 with loss 1.3054
# Classifier Epoch 7, Average Loss: 1.3054
# Classifier Epoch 8, Average Loss: 1.3791
# Saved best classifier model at epoch 9 with loss 1.0548
# Classifier Epoch 9, Average Loss: 1.0548
# Classifier Epoch 10, Average Loss: 1.5237
# Classifier Epoch 11, Average Loss: 1.6468
# Classifier Epoch 12, Average Loss: 1.1327
# Saved best classifier model at epoch 13 with loss 1.0502
# Classifier Epoch 13, Average Loss: 1.0502
# Saved best classifier model at epoch 14 with loss 0.7661
# Classifier Epoch 14, Average Loss: 0.7661
# Saved best classifier model at epoch 15 with loss 0.5250
# Classifier Epoch 15, Average Loss: 0.5250
# Classifier Epoch 16, Average Loss: 0.6212
# Saved best classifier model at epoch 17 with loss 0.5026
# Classifier Epoch 17, Average Loss: 0.5026
# Classifier Epoch 18, Average Loss: 0.5763
# Classifier Epoch 19, Average Loss: 0.7100
# Saved best classifier model at epoch 20 with loss 0.5026
# Classifier Epoch 20, Average Loss: 0.5026
# Classifier Epoch 21, Average Loss: 0.5436
# Saved best classifier model at epoch 22 with loss 0.2927
# Classifier Epoch 22, Average Loss: 0.2927
# Classifier Epoch 23, Average Loss: 0.5072
# Classifier Epoch 24, Average Loss: 0.4575
# Classifier Epoch 25, Average Loss: 0.5064
# Saved best classifier model at epoch 26 with loss 0.1743
# Classifier Epoch 26, Average Loss: 0.1743
# Classifier Epoch 27, Average Loss: 0.2862
# Classifier Epoch 28, Average Loss: 0.2345
# Classifier Epoch 29, Average Loss: 0.3492
# Saved best classifier model at epoch 30 with loss 0.1383
# Classifier Epoch 30, Average Loss: 0.1383
# Saved best classifier model at epoch 31 with loss 0.0561
# Classifier Epoch 31, Average Loss: 0.0561
# Saved best classifier model at epoch 32 with loss 0.0240
# Classifier Epoch 32, Average Loss: 0.0240
# Saved best classifier model at epoch 33 with loss 0.0186
# Classifier Epoch 33, Average Loss: 0.0186
# Saved best classifier model at epoch 34 with loss 0.0180
# Classifier Epoch 34, Average Loss: 0.0180
# Classifier Epoch 35, Average Loss: 0.0195
# Saved best classifier model at epoch 36 with loss 0.0101
# Classifier Epoch 36, Average Loss: 0.0101
# Classifier Epoch 37, Average Loss: 0.0109
# Classifier Epoch 38, Average Loss: 0.0161
# Classifier Epoch 39, Average Loss: 0.2616
# Classifier Epoch 40, Average Loss: 1.3798
# Classifier Epoch 41, Average Loss: 0.8015
# Classifier Epoch 42, Average Loss: 0.9506
# Classifier Epoch 43, Average Loss: 0.5842
# Classifier Epoch 44, Average Loss: 0.7393
# Classifier Epoch 45, Average Loss: 0.1646
# Classifier Epoch 46, Average Loss: 0.1588
# Classifier Epoch 47, Average Loss: 0.1105
# Classifier Epoch 48, Average Loss: 0.0438
# Classifier Epoch 49, Average Loss: 0.0279
# Classifier Epoch 50, Average Loss: 0.0188
# Training the GAN...
# GAN Epoch [1/50] Batch [0/125] D Loss: 1.3823 G Loss: 260743.8594
# GAN Epoch [1/50] Batch [10/125] D Loss: 1.1190 G Loss: 417215.0625
# GAN Epoch [1/50] Batch [20/125] D Loss: 1.0253 G Loss: 1481871.1250
# GAN Epoch [1/50] Batch [30/125] D Loss: 0.9709 G Loss: 199696.7188
# GAN Epoch [1/50] Batch [40/125] D Loss: 0.9498 G Loss: 436755.4062
# GAN Epoch [1/50] Batch [50/125] D Loss: 0.8944 G Loss: 985507.0000
# GAN Epoch [1/50] Batch [60/125] D Loss: 0.8323 G Loss: 532190.1250
# GAN Epoch [1/50] Batch [70/125] D Loss: 0.7661 G Loss: 639915.1875
# GAN Epoch [1/50] Batch [80/125] D Loss: 0.7442 G Loss: 163376.7969
# GAN Epoch [1/50] Batch [90/125] D Loss: 0.7190 G Loss: 214502.1719
# GAN Epoch [1/50] Batch [100/125] D Loss: 0.7359 G Loss: 1484591.8750
# GAN Epoch [1/50] Batch [110/125] D Loss: 0.6240 G Loss: 285302.0312
# GAN Epoch [1/50] Batch [120/125] D Loss: 0.5263 G Loss: 309858.8750
# Saved best generator model at epoch 1 with average G Loss 739138.6539
# GAN Epoch [1/50], Average Generator Loss: 739138.6539
# GAN Epoch [2/50] Batch [0/125] D Loss: 0.5525 G Loss: 311196.3438
# GAN Epoch [2/50] Batch [10/125] D Loss: 0.5195 G Loss: 2644279.5000
# GAN Epoch [2/50] Batch [20/125] D Loss: 0.4943 G Loss: 173569.8594
# GAN Epoch [2/50] Batch [30/125] D Loss: 0.4432 G Loss: 301901.2188
# GAN Epoch [2/50] Batch [40/125] D Loss: 0.3865 G Loss: 1029716.2500
# GAN Epoch [2/50] Batch [50/125] D Loss: 0.3406 G Loss: 339462.6562
# GAN Epoch [2/50] Batch [60/125] D Loss: 0.3424 G Loss: 1025162.4375
# GAN Epoch [2/50] Batch [70/125] D Loss: 0.3434 G Loss: 334127.8438
# GAN Epoch [2/50] Batch [80/125] D Loss: 0.2933 G Loss: 635435.6250
# GAN Epoch [2/50] Batch [90/125] D Loss: 0.2692 G Loss: 155093.5469
# GAN Epoch [2/50] Batch [100/125] D Loss: 0.2582 G Loss: 920060.8125
# GAN Epoch [2/50] Batch [110/125] D Loss: 0.2879 G Loss: 511453.0938
# GAN Epoch [2/50] Batch [120/125] D Loss: 0.2184 G Loss: 846320.4375
# Saved best generator model at epoch 2 with average G Loss 737213.0270
# GAN Epoch [2/50], Average Generator Loss: 737213.0270
# GAN Epoch [3/50] Batch [0/125] D Loss: 0.2204 G Loss: 1644646.3750
# GAN Epoch [3/50] Batch [10/125] D Loss: 0.2020 G Loss: 905428.1875
# GAN Epoch [3/50] Batch [20/125] D Loss: 0.2163 G Loss: 1094811.2500
# GAN Epoch [3/50] Batch [30/125] D Loss: 0.1630 G Loss: 2256270.7500
# GAN Epoch [3/50] Batch [40/125] D Loss: 0.1951 G Loss: 344009.8438
# GAN Epoch [3/50] Batch [50/125] D Loss: 0.1854 G Loss: 287118.7188
# GAN Epoch [3/50] Batch [60/125] D Loss: 0.1534 G Loss: 1470202.6250
# GAN Epoch [3/50] Batch [70/125] D Loss: 0.1639 G Loss: 2467287.7500
# GAN Epoch [3/50] Batch [80/125] D Loss: 0.1753 G Loss: 495930.0000
# GAN Epoch [3/50] Batch [90/125] D Loss: 0.1496 G Loss: 585915.8125
# GAN Epoch [3/50] Batch [100/125] D Loss: 0.1335 G Loss: 297192.1562
# GAN Epoch [3/50] Batch [110/125] D Loss: 0.1327 G Loss: 282996.8438
# GAN Epoch [3/50] Batch [120/125] D Loss: 0.1325 G Loss: 590392.2500
# GAN Epoch [3/50], Average Generator Loss: 738157.2994
# GAN Epoch [4/50] Batch [0/125] D Loss: 0.1549 G Loss: 569028.2500
# GAN Epoch [4/50] Batch [10/125] D Loss: 0.1321 G Loss: 1459956.3750
# GAN Epoch [4/50] Batch [20/125] D Loss: 0.1260 G Loss: 246790.2812
# GAN Epoch [4/50] Batch [30/125] D Loss: 0.1251 G Loss: 398963.9062
# GAN Epoch [4/50] Batch [40/125] D Loss: 0.1088 G Loss: 320943.9688
# GAN Epoch [4/50] Batch [50/125] D Loss: 0.1088 G Loss: 1070952.0000
# GAN Epoch [4/50] Batch [60/125] D Loss: 0.1061 G Loss: 822862.6250
# GAN Epoch [4/50] Batch [70/125] D Loss: 0.0904 G Loss: 511641.9688
# GAN Epoch [4/50] Batch [80/125] D Loss: 0.0949 G Loss: 724558.1250
# GAN Epoch [4/50] Batch [90/125] D Loss: 0.0857 G Loss: 1172525.8750
# GAN Epoch [4/50] Batch [100/125] D Loss: 0.0922 G Loss: 167234.3750
# GAN Epoch [4/50] Batch [110/125] D Loss: 0.0890 G Loss: 626207.4375
# GAN Epoch [4/50] Batch [120/125] D Loss: 0.1068 G Loss: 710608.4375
# GAN Epoch [4/50], Average Generator Loss: 740635.6242
# GAN Epoch [5/50] Batch [0/125] D Loss: 0.0788 G Loss: 1542318.5000
# GAN Epoch [5/50] Batch [10/125] D Loss: 0.0867 G Loss: 1624688.0000
# GAN Epoch [5/50] Batch [20/125] D Loss: 0.1014 G Loss: 3321447.7500
# GAN Epoch [5/50] Batch [30/125] D Loss: 0.0729 G Loss: 1344693.7500
# GAN Epoch [5/50] Batch [40/125] D Loss: 0.0815 G Loss: 1019443.0625
# GAN Epoch [5/50] Batch [50/125] D Loss: 0.0848 G Loss: 449698.7188
# GAN Epoch [5/50] Batch [60/125] D Loss: 0.0681 G Loss: 510179.2188
# GAN Epoch [5/50] Batch [70/125] D Loss: 0.0728 G Loss: 436300.6562
# GAN Epoch [5/50] Batch [80/125] D Loss: 0.0688 G Loss: 37588.7773
# GAN Epoch [5/50] Batch [90/125] D Loss: 0.0728 G Loss: 109930.3672
# GAN Epoch [5/50] Batch [100/125] D Loss: 0.0776 G Loss: 1543136.2500
# GAN Epoch [5/50] Batch [110/125] D Loss: 0.0753 G Loss: 181191.1250
# GAN Epoch [5/50] Batch [120/125] D Loss: 0.0541 G Loss: 511089.2812
# Saved best generator model at epoch 5 with average G Loss 735926.5104
# GAN Epoch [5/50], Average Generator Loss: 735926.5104
# GAN Epoch [6/50] Batch [0/125] D Loss: 0.0569 G Loss: 529544.2500
# GAN Epoch [6/50] Batch [10/125] D Loss: 0.0672 G Loss: 339433.5312
# GAN Epoch [6/50] Batch [20/125] D Loss: 0.0602 G Loss: 544831.3125
# GAN Epoch [6/50] Batch [30/125] D Loss: 0.0569 G Loss: 830741.0625
# GAN Epoch [6/50] Batch [40/125] D Loss: 0.0502 G Loss: 54131.8711
# GAN Epoch [6/50] Batch [50/125] D Loss: 0.0537 G Loss: 297033.0625
# GAN Epoch [6/50] Batch [60/125] D Loss: 0.0529 G Loss: 2061514.7500
# GAN Epoch [6/50] Batch [70/125] D Loss: 0.0421 G Loss: 2036947.7500
# GAN Epoch [6/50] Batch [80/125] D Loss: 0.0473 G Loss: 139308.1562
# GAN Epoch [6/50] Batch [90/125] D Loss: 0.0404 G Loss: 1014302.6875
# GAN Epoch [6/50] Batch [100/125] D Loss: 0.0510 G Loss: 1646230.7500
# GAN Epoch [6/50] Batch [110/125] D Loss: 0.0420 G Loss: 171096.1875
# GAN Epoch [6/50] Batch [120/125] D Loss: 0.0430 G Loss: 353807.5625
# Saved best generator model at epoch 6 with average G Loss 734919.4544
# GAN Epoch [6/50], Average Generator Loss: 734919.4544
# GAN Epoch [7/50] Batch [0/125] D Loss: 0.0387 G Loss: 207771.5781
# GAN Epoch [7/50] Batch [10/125] D Loss: 0.0429 G Loss: 2243578.5000
# GAN Epoch [7/50] Batch [20/125] D Loss: 0.0446 G Loss: 158043.1719
# GAN Epoch [7/50] Batch [30/125] D Loss: 0.0403 G Loss: 451342.0625
# GAN Epoch [7/50] Batch [40/125] D Loss: 0.0414 G Loss: 444476.1875
# GAN Epoch [7/50] Batch [50/125] D Loss: 0.0540 G Loss: 343292.9688
# GAN Epoch [7/50] Batch [60/125] D Loss: 0.1000 G Loss: 466313.0312
# GAN Epoch [7/50] Batch [70/125] D Loss: 0.1410 G Loss: 1246673.8750
# GAN Epoch [7/50] Batch [80/125] D Loss: 0.0791 G Loss: 434143.2812
# GAN Epoch [7/50] Batch [90/125] D Loss: 0.0553 G Loss: 122628.4062
# GAN Epoch [7/50] Batch [100/125] D Loss: 0.0422 G Loss: 261830.0000
# GAN Epoch [7/50] Batch [110/125] D Loss: 0.0612 G Loss: 369835.6875
# GAN Epoch [7/50] Batch [120/125] D Loss: 0.0589 G Loss: 953563.2500
# Saved best generator model at epoch 7 with average G Loss 734530.0525
# GAN Epoch [7/50], Average Generator Loss: 734530.0525
# GAN Epoch [8/50] Batch [0/125] D Loss: 0.0417 G Loss: 722331.2500
# GAN Epoch [8/50] Batch [10/125] D Loss: 0.0596 G Loss: 262392.9062
# GAN Epoch [8/50] Batch [20/125] D Loss: 0.0485 G Loss: 951856.5625
# GAN Epoch [8/50] Batch [30/125] D Loss: 0.0528 G Loss: 530534.3750
# GAN Epoch [8/50] Batch [40/125] D Loss: 0.0325 G Loss: 263974.5312
# GAN Epoch [8/50] Batch [50/125] D Loss: 0.0345 G Loss: 145527.6562
# GAN Epoch [8/50] Batch [60/125] D Loss: 0.0326 G Loss: 957292.9375
# GAN Epoch [8/50] Batch [70/125] D Loss: 0.0281 G Loss: 1154243.0000
# GAN Epoch [8/50] Batch [80/125] D Loss: 0.0253 G Loss: 2387779.7500
# GAN Epoch [8/50] Batch [90/125] D Loss: 0.0313 G Loss: 1330949.6250
# GAN Epoch [8/50] Batch [100/125] D Loss: 0.0246 G Loss: 662650.6250
# GAN Epoch [8/50] Batch [110/125] D Loss: 0.0262 G Loss: 887593.3750
# GAN Epoch [8/50] Batch [120/125] D Loss: 0.0265 G Loss: 1187836.1250
# GAN Epoch [8/50], Average Generator Loss: 735699.3511
# GAN Epoch [9/50] Batch [0/125] D Loss: 0.0845 G Loss: 593537.7500
# GAN Epoch [9/50] Batch [10/125] D Loss: 0.0355 G Loss: 191870.9688
# GAN Epoch [9/50] Batch [20/125] D Loss: 0.0253 G Loss: 163453.2500
# GAN Epoch [9/50] Batch [30/125] D Loss: 0.0242 G Loss: 395324.6562
# GAN Epoch [9/50] Batch [40/125] D Loss: 0.0256 G Loss: 286472.4688
# GAN Epoch [9/50] Batch [50/125] D Loss: 0.0231 G Loss: 2077917.8750
# GAN Epoch [9/50] Batch [60/125] D Loss: 0.0210 G Loss: 1184041.8750
# GAN Epoch [9/50] Batch [70/125] D Loss: 0.0226 G Loss: 448767.8125
# GAN Epoch [9/50] Batch [80/125] D Loss: 0.0199 G Loss: 1513054.6250
# GAN Epoch [9/50] Batch [90/125] D Loss: 0.0192 G Loss: 1507536.6250
# GAN Epoch [9/50] Batch [100/125] D Loss: 0.0195 G Loss: 748866.6250
# GAN Epoch [9/50] Batch [110/125] D Loss: 0.0239 G Loss: 145625.9688
# GAN Epoch [9/50] Batch [120/125] D Loss: 0.0252 G Loss: 529150.1875
# Saved best generator model at epoch 9 with average G Loss 732847.3109
# GAN Epoch [9/50], Average Generator Loss: 732847.3109
# GAN Epoch [10/50] Batch [0/125] D Loss: 0.0246 G Loss: 104839.8281
# GAN Epoch [10/50] Batch [10/125] D Loss: 0.0238 G Loss: 705803.5000
# GAN Epoch [10/50] Batch [20/125] D Loss: 0.0349 G Loss: 25239.7363
# GAN Epoch [10/50] Batch [30/125] D Loss: 0.0228 G Loss: 484686.5938
# GAN Epoch [10/50] Batch [40/125] D Loss: 0.0188 G Loss: 742796.4375
# GAN Epoch [10/50] Batch [50/125] D Loss: 0.0221 G Loss: 89862.7656
# GAN Epoch [10/50] Batch [60/125] D Loss: 0.0349 G Loss: 407087.1875
# GAN Epoch [10/50] Batch [70/125] D Loss: 0.0273 G Loss: 504015.3438
# GAN Epoch [10/50] Batch [80/125] D Loss: 0.0178 G Loss: 1147496.5000
# GAN Epoch [10/50] Batch [90/125] D Loss: 0.0176 G Loss: 886826.3125
# GAN Epoch [10/50] Batch [100/125] D Loss: 0.0191 G Loss: 172887.3438
# GAN Epoch [10/50] Batch [110/125] D Loss: 0.0253 G Loss: 188531.8594
# GAN Epoch [10/50] Batch [120/125] D Loss: 0.0152 G Loss: 623419.8750
# Saved best generator model at epoch 10 with average G Loss 732592.5770
# GAN Epoch [10/50], Average Generator Loss: 732592.5770
# GAN Epoch [11/50] Batch [0/125] D Loss: 0.0154 G Loss: 60697.5234
# GAN Epoch [11/50] Batch [10/125] D Loss: 0.0195 G Loss: 60217.2930
# GAN Epoch [11/50] Batch [20/125] D Loss: 0.0346 G Loss: 119400.3906
# GAN Epoch [11/50] Batch [30/125] D Loss: 0.0217 G Loss: 242210.5938
# GAN Epoch [11/50] Batch [40/125] D Loss: 0.0472 G Loss: 775467.2500
# GAN Epoch [11/50] Batch [50/125] D Loss: 0.0213 G Loss: 1117897.2500
# GAN Epoch [11/50] Batch [60/125] D Loss: 0.0152 G Loss: 2600558.7500
# GAN Epoch [11/50] Batch [70/125] D Loss: 0.0162 G Loss: 1588911.1250
# GAN Epoch [11/50] Batch [80/125] D Loss: 0.0141 G Loss: 297289.9688
# GAN Epoch [11/50] Batch [90/125] D Loss: 0.0169 G Loss: 233146.9375
# GAN Epoch [11/50] Batch [100/125] D Loss: 0.0155 G Loss: 1543240.1250
# GAN Epoch [11/50] Batch [110/125] D Loss: 0.0137 G Loss: 557009.0625
# GAN Epoch [11/50] Batch [120/125] D Loss: 0.0176 G Loss: 1485199.8750
# GAN Epoch [11/50], Average Generator Loss: 739909.1948
# GAN Epoch [12/50] Batch [0/125] D Loss: 0.0137 G Loss: 294953.6875
# GAN Epoch [12/50] Batch [10/125] D Loss: 0.0208 G Loss: 272496.7500
# GAN Epoch [12/50] Batch [20/125] D Loss: 0.0138 G Loss: 753665.7500
# GAN Epoch [12/50] Batch [30/125] D Loss: 0.0117 G Loss: 2050949.8750
# GAN Epoch [12/50] Batch [40/125] D Loss: 0.0143 G Loss: 579669.6875
# GAN Epoch [12/50] Batch [50/125] D Loss: 0.0165 G Loss: 420897.5312
# GAN Epoch [12/50] Batch [60/125] D Loss: 0.0369 G Loss: 1139127.7500
# GAN Epoch [12/50] Batch [70/125] D Loss: 0.0146 G Loss: 793638.4375
# GAN Epoch [12/50] Batch [80/125] D Loss: 0.0179 G Loss: 383071.7188
# GAN Epoch [12/50] Batch [90/125] D Loss: 0.0192 G Loss: 2684351.5000
# GAN Epoch [12/50] Batch [100/125] D Loss: 0.0179 G Loss: 251345.1562
# GAN Epoch [12/50] Batch [110/125] D Loss: 0.0149 G Loss: 981488.6250
# GAN Epoch [12/50] Batch [120/125] D Loss: 0.0122 G Loss: 461958.6250
# Saved best generator model at epoch 12 with average G Loss 731129.1046
# GAN Epoch [12/50], Average Generator Loss: 731129.1046
# GAN Epoch [13/50] Batch [0/125] D Loss: 0.0103 G Loss: 2693724.2500
# GAN Epoch [13/50] Batch [10/125] D Loss: 0.0090 G Loss: 1084203.6250
# GAN Epoch [13/50] Batch [20/125] D Loss: 0.0108 G Loss: 403051.1250
# GAN Epoch [13/50] Batch [30/125] D Loss: 0.0091 G Loss: 567980.1875
# GAN Epoch [13/50] Batch [40/125] D Loss: 0.0104 G Loss: 1517162.0000
# GAN Epoch [13/50] Batch [50/125] D Loss: 0.0107 G Loss: 617565.7500
# GAN Epoch [13/50] Batch [60/125] D Loss: 0.0100 G Loss: 1005269.0625
# GAN Epoch [13/50] Batch [70/125] D Loss: 0.0082 G Loss: 699984.9375
# GAN Epoch [13/50] Batch [80/125] D Loss: 0.0090 G Loss: 438563.6562
# GAN Epoch [13/50] Batch [90/125] D Loss: 0.0098 G Loss: 1303427.1250
# GAN Epoch [13/50] Batch [100/125] D Loss: 0.0100 G Loss: 74056.4141
# GAN Epoch [13/50] Batch [110/125] D Loss: 0.0101 G Loss: 160015.6094
# GAN Epoch [13/50] Batch [120/125] D Loss: 0.0090 G Loss: 239944.1250
# GAN Epoch [13/50], Average Generator Loss: 731638.4676
# GAN Epoch [14/50] Batch [0/125] D Loss: 0.0081 G Loss: 355548.1250
# GAN Epoch [14/50] Batch [10/125] D Loss: 0.0096 G Loss: 571048.2500
# GAN Epoch [14/50] Batch [20/125] D Loss: 0.0084 G Loss: 637113.8750
# GAN Epoch [14/50] Batch [30/125] D Loss: 0.0067 G Loss: 935838.8125
# GAN Epoch [14/50] Batch [40/125] D Loss: 0.0070 G Loss: 571628.0000
# GAN Epoch [14/50] Batch [50/125] D Loss: 0.0110 G Loss: 1562602.2500
# GAN Epoch [14/50] Batch [60/125] D Loss: 0.0077 G Loss: 1697045.3750
# GAN Epoch [14/50] Batch [70/125] D Loss: 0.0105 G Loss: 334229.0625
# GAN Epoch [14/50] Batch [80/125] D Loss: 0.0125 G Loss: 541532.3750
# GAN Epoch [14/50] Batch [90/125] D Loss: 0.0126 G Loss: 508013.5938
# GAN Epoch [14/50] Batch [100/125] D Loss: 0.0092 G Loss: 1087960.1250
# GAN Epoch [14/50] Batch [110/125] D Loss: 0.0136 G Loss: 1693365.0000
# GAN Epoch [14/50] Batch [120/125] D Loss: 0.0070 G Loss: 1000437.0000
# GAN Epoch [14/50], Average Generator Loss: 731862.5811
# GAN Epoch [15/50] Batch [0/125] D Loss: 0.0073 G Loss: 1192786.5000
# GAN Epoch [15/50] Batch [10/125] D Loss: 0.0072 G Loss: 1492450.6250
# GAN Epoch [15/50] Batch [20/125] D Loss: 0.0111 G Loss: 416839.7812
# GAN Epoch [15/50] Batch [30/125] D Loss: 0.0065 G Loss: 445172.6875
# GAN Epoch [15/50] Batch [40/125] D Loss: 0.0070 G Loss: 1763265.5000
# GAN Epoch [15/50] Batch [50/125] D Loss: 0.0082 G Loss: 378365.4688
# GAN Epoch [15/50] Batch [60/125] D Loss: 0.0070 G Loss: 219986.8125
# GAN Epoch [15/50] Batch [70/125] D Loss: 0.0074 G Loss: 500927.0938
# GAN Epoch [15/50] Batch [80/125] D Loss: 0.0065 G Loss: 612326.0625
# GAN Epoch [15/50] Batch [90/125] D Loss: 0.0286 G Loss: 464449.5312
# GAN Epoch [15/50] Batch [100/125] D Loss: 0.0134 G Loss: 434831.3438
# GAN Epoch [15/50] Batch [110/125] D Loss: 0.0074 G Loss: 1177111.7500
# GAN Epoch [15/50] Batch [120/125] D Loss: 0.0069 G Loss: 296115.1250
# Saved best generator model at epoch 15 with average G Loss 728404.1002
# GAN Epoch [15/50], Average Generator Loss: 728404.1002
# GAN Epoch [16/50] Batch [0/125] D Loss: 0.0091 G Loss: 378501.8750
# GAN Epoch [16/50] Batch [10/125] D Loss: 0.0058 G Loss: 473645.0312
# GAN Epoch [16/50] Batch [20/125] D Loss: 0.0066 G Loss: 260207.5625
# GAN Epoch [16/50] Batch [30/125] D Loss: 0.0094 G Loss: 2442981.2500
# GAN Epoch [16/50] Batch [40/125] D Loss: 0.0060 G Loss: 919871.9375
# GAN Epoch [16/50] Batch [50/125] D Loss: 0.0074 G Loss: 219011.7969
# GAN Epoch [16/50] Batch [60/125] D Loss: 0.0069 G Loss: 1242651.0000
# GAN Epoch [16/50] Batch [70/125] D Loss: 0.0048 G Loss: 2301927.0000
# GAN Epoch [16/50] Batch [80/125] D Loss: 0.0057 G Loss: 1249496.5000
# GAN Epoch [16/50] Batch [90/125] D Loss: 0.0053 G Loss: 273686.8125
# GAN Epoch [16/50] Batch [100/125] D Loss: 0.0055 G Loss: 59465.4258
# GAN Epoch [16/50] Batch [110/125] D Loss: 0.0062 G Loss: 196646.4844
# GAN Epoch [16/50] Batch [120/125] D Loss: 0.0078 G Loss: 201900.0156
# GAN Epoch [16/50], Average Generator Loss: 730745.6901
# GAN Epoch [17/50] Batch [0/125] D Loss: 0.0071 G Loss: 424781.9688
# GAN Epoch [17/50] Batch [10/125] D Loss: 0.0063 G Loss: 827211.3750
# GAN Epoch [17/50] Batch [20/125] D Loss: 0.0062 G Loss: 429605.8125
# GAN Epoch [17/50] Batch [30/125] D Loss: 0.0060 G Loss: 296129.3438
# GAN Epoch [17/50] Batch [40/125] D Loss: 0.0056 G Loss: 1026228.8750
# GAN Epoch [17/50] Batch [50/125] D Loss: 0.0057 G Loss: 757467.4375
# GAN Epoch [17/50] Batch [60/125] D Loss: 0.0073 G Loss: 341768.8125
# GAN Epoch [17/50] Batch [70/125] D Loss: 0.0066 G Loss: 831985.5625
# GAN Epoch [17/50] Batch [80/125] D Loss: 0.0075 G Loss: 62116.4492
# GAN Epoch [17/50] Batch [90/125] D Loss: 0.0074 G Loss: 120916.3359
# GAN Epoch [17/50] Batch [100/125] D Loss: 0.0056 G Loss: 2203226.2500
# GAN Epoch [17/50] Batch [110/125] D Loss: 0.0042 G Loss: 1218729.0000
# GAN Epoch [17/50] Batch [120/125] D Loss: 0.0043 G Loss: 929983.3750
# Saved best generator model at epoch 17 with average G Loss 726980.8449
# GAN Epoch [17/50], Average Generator Loss: 726980.8449
# GAN Epoch [18/50] Batch [0/125] D Loss: 0.0051 G Loss: 164464.4688
# GAN Epoch [18/50] Batch [10/125] D Loss: 0.0045 G Loss: 1241874.1250
# GAN Epoch [18/50] Batch [20/125] D Loss: 0.0046 G Loss: 545805.8125
# GAN Epoch [18/50] Batch [30/125] D Loss: 0.0051 G Loss: 1469069.7500
# GAN Epoch [18/50] Batch [40/125] D Loss: 0.0068 G Loss: 329959.7188
# GAN Epoch [18/50] Batch [50/125] D Loss: 0.0084 G Loss: 161235.0156
# GAN Epoch [18/50] Batch [60/125] D Loss: 0.0042 G Loss: 488113.8125
# GAN Epoch [18/50] Batch [70/125] D Loss: 0.0047 G Loss: 660031.6875
# GAN Epoch [18/50] Batch [80/125] D Loss: 0.0037 G Loss: 1057779.0000
# GAN Epoch [18/50] Batch [90/125] D Loss: 0.0047 G Loss: 495315.8125
# GAN Epoch [18/50] Batch [100/125] D Loss: 0.0064 G Loss: 551641.5000
# GAN Epoch [18/50] Batch [110/125] D Loss: 0.0087 G Loss: 181538.7969
# GAN Epoch [18/50] Batch [120/125] D Loss: 0.0041 G Loss: 891821.5000
# GAN Epoch [18/50], Average Generator Loss: 727341.0924
# GAN Epoch [19/50] Batch [0/125] D Loss: 0.0050 G Loss: 533980.0625
# GAN Epoch [19/50] Batch [10/125] D Loss: 0.0087 G Loss: 241009.1406
# GAN Epoch [19/50] Batch [20/125] D Loss: 0.0038 G Loss: 1636328.1250
# GAN Epoch [19/50] Batch [30/125] D Loss: 0.0034 G Loss: 888683.0625
# GAN Epoch [19/50] Batch [40/125] D Loss: 0.0059 G Loss: 161501.4688
# GAN Epoch [19/50] Batch [50/125] D Loss: 0.0045 G Loss: 1106130.2500
# GAN Epoch [19/50] Batch [60/125] D Loss: 0.0051 G Loss: 332502.8750
# GAN Epoch [19/50] Batch [70/125] D Loss: 0.0041 G Loss: 710462.1250
# GAN Epoch [19/50] Batch [80/125] D Loss: 0.0037 G Loss: 826654.0000
# GAN Epoch [19/50] Batch [90/125] D Loss: 0.0035 G Loss: 2148858.2500
# GAN Epoch [19/50] Batch [100/125] D Loss: 0.0046 G Loss: 76938.3047
# GAN Epoch [19/50] Batch [110/125] D Loss: 0.0033 G Loss: 3093466.7500
# GAN Epoch [19/50] Batch [120/125] D Loss: 0.0050 G Loss: 173378.9531
# Saved best generator model at epoch 19 with average G Loss 724996.9640
# GAN Epoch [19/50], Average Generator Loss: 724996.9640
# GAN Epoch [20/50] Batch [0/125] D Loss: 0.0041 G Loss: 191693.0000
# GAN Epoch [20/50] Batch [10/125] D Loss: 0.0044 G Loss: 54347.3594
# GAN Epoch [20/50] Batch [20/125] D Loss: 0.0041 G Loss: 184395.2812
# GAN Epoch [20/50] Batch [30/125] D Loss: 0.0041 G Loss: 647004.0000
# GAN Epoch [20/50] Batch [40/125] D Loss: 0.0045 G Loss: 951857.6875
# GAN Epoch [20/50] Batch [50/125] D Loss: 0.0088 G Loss: 34360.8828
# GAN Epoch [20/50] Batch [60/125] D Loss: 0.0047 G Loss: 391245.6562
# GAN Epoch [20/50] Batch [70/125] D Loss: 0.0042 G Loss: 299808.4375
# GAN Epoch [20/50] Batch [80/125] D Loss: 0.0030 G Loss: 351594.6562
# GAN Epoch [20/50] Batch [90/125] D Loss: 0.0047 G Loss: 390701.1875
# GAN Epoch [20/50] Batch [100/125] D Loss: 0.0037 G Loss: 601831.1875
# GAN Epoch [20/50] Batch [110/125] D Loss: 0.0040 G Loss: 469012.6875
# GAN Epoch [20/50] Batch [120/125] D Loss: 0.0035 G Loss: 3335311.2500
# GAN Epoch [20/50], Average Generator Loss: 725052.9985
# GAN Epoch [21/50] Batch [0/125] D Loss: 0.0044 G Loss: 352208.3750
# GAN Epoch [21/50] Batch [10/125] D Loss: 0.0062 G Loss: 312116.5938
# GAN Epoch [21/50] Batch [20/125] D Loss: 0.0049 G Loss: 219279.5156
# GAN Epoch [21/50] Batch [30/125] D Loss: 0.0035 G Loss: 375693.0000
# GAN Epoch [21/50] Batch [40/125] D Loss: 0.0030 G Loss: 293368.0312
# GAN Epoch [21/50] Batch [50/125] D Loss: 0.0040 G Loss: 1779829.5000
# GAN Epoch [21/50] Batch [60/125] D Loss: 0.0047 G Loss: 297550.2188
# GAN Epoch [21/50] Batch [70/125] D Loss: 0.0027 G Loss: 371693.1562
# GAN Epoch [21/50] Batch [80/125] D Loss: 0.0076 G Loss: 249180.9062
# GAN Epoch [21/50] Batch [90/125] D Loss: 0.0033 G Loss: 60210.8984
# GAN Epoch [21/50] Batch [100/125] D Loss: 0.0030 G Loss: 504991.0000
# GAN Epoch [21/50] Batch [110/125] D Loss: 0.0040 G Loss: 793735.0625
# GAN Epoch [21/50] Batch [120/125] D Loss: 0.0047 G Loss: 300414.8750
# GAN Epoch [21/50], Average Generator Loss: 726211.7553
# GAN Epoch [22/50] Batch [0/125] D Loss: 0.0045 G Loss: 1374136.5000
# GAN Epoch [22/50] Batch [10/125] D Loss: 0.0046 G Loss: 83677.4766
# GAN Epoch [22/50] Batch [20/125] D Loss: 0.0049 G Loss: 545350.0000
# GAN Epoch [22/50] Batch [30/125] D Loss: 0.0038 G Loss: 67521.3203
# GAN Epoch [22/50] Batch [40/125] D Loss: 0.0024 G Loss: 958700.0000
# GAN Epoch [22/50] Batch [50/125] D Loss: 0.0044 G Loss: 783801.7500
# GAN Epoch [22/50] Batch [60/125] D Loss: 0.0059 G Loss: 166966.1250
# GAN Epoch [22/50] Batch [70/125] D Loss: 0.0029 G Loss: 265511.8125
# GAN Epoch [22/50] Batch [80/125] D Loss: 0.0035 G Loss: 306445.4062
# GAN Epoch [22/50] Batch [90/125] D Loss: 0.0048 G Loss: 243727.9688
# GAN Epoch [22/50] Batch [100/125] D Loss: 0.0022 G Loss: 975979.8125
# GAN Epoch [22/50] Batch [110/125] D Loss: 0.0059 G Loss: 405771.0938
# GAN Epoch [22/50] Batch [120/125] D Loss: 0.0039 G Loss: 128553.7422
# Saved best generator model at epoch 22 with average G Loss 724389.2836
# GAN Epoch [22/50], Average Generator Loss: 724389.2836
# GAN Epoch [23/50] Batch [0/125] D Loss: 0.0055 G Loss: 266241.7500
# GAN Epoch [23/50] Batch [10/125] D Loss: 0.0031 G Loss: 248510.8125
# GAN Epoch [23/50] Batch [20/125] D Loss: 0.0039 G Loss: 87675.6875
# GAN Epoch [23/50] Batch [30/125] D Loss: 0.0033 G Loss: 326993.8750
# GAN Epoch [23/50] Batch [40/125] D Loss: 0.0026 G Loss: 437449.3438
# GAN Epoch [23/50] Batch [50/125] D Loss: 0.0042 G Loss: 1633206.0000
# GAN Epoch [23/50] Batch [60/125] D Loss: 0.0029 G Loss: 1023681.6875
# GAN Epoch [23/50] Batch [70/125] D Loss: 0.0047 G Loss: 511431.4375
# GAN Epoch [23/50] Batch [80/125] D Loss: 0.0071 G Loss: 273992.0938
# GAN Epoch [23/50] Batch [90/125] D Loss: 0.0067 G Loss: 218980.3594
# GAN Epoch [23/50] Batch [100/125] D Loss: 0.0049 G Loss: 3082010.7500
# GAN Epoch [23/50] Batch [110/125] D Loss: 0.0065 G Loss: 450635.5938
# GAN Epoch [23/50] Batch [120/125] D Loss: 0.0060 G Loss: 257470.7812
# Saved best generator model at epoch 23 with average G Loss 722161.0342
# GAN Epoch [23/50], Average Generator Loss: 722161.0342
# GAN Epoch [24/50] Batch [0/125] D Loss: 0.0041 G Loss: 1122358.3750
# GAN Epoch [24/50] Batch [10/125] D Loss: 0.0054 G Loss: 1072409.2500
# GAN Epoch [24/50] Batch [20/125] D Loss: 0.0060 G Loss: 147445.4219
# GAN Epoch [24/50] Batch [30/125] D Loss: 0.0043 G Loss: 395767.1562
# GAN Epoch [24/50] Batch [40/125] D Loss: 0.0051 G Loss: 238118.5312
# GAN Epoch [24/50] Batch [50/125] D Loss: 0.0065 G Loss: 196732.1562
# GAN Epoch [24/50] Batch [60/125] D Loss: 0.0065 G Loss: 441583.2188
# GAN Epoch [24/50] Batch [70/125] D Loss: 0.0047 G Loss: 447952.6250
# GAN Epoch [24/50] Batch [80/125] D Loss: 0.0036 G Loss: 501959.5000
# GAN Epoch [24/50] Batch [90/125] D Loss: 0.0049 G Loss: 1065568.2500
# GAN Epoch [24/50] Batch [100/125] D Loss: 0.0041 G Loss: 280851.6875
# GAN Epoch [24/50] Batch [110/125] D Loss: 0.0052 G Loss: 251462.2031
# GAN Epoch [24/50] Batch [120/125] D Loss: 0.0028 G Loss: 649563.8750
# Saved best generator model at epoch 24 with average G Loss 721751.0300
# GAN Epoch [24/50], Average Generator Loss: 721751.0300
# GAN Epoch [25/50] Batch [0/125] D Loss: 0.0049 G Loss: 305178.6250
# GAN Epoch [25/50] Batch [10/125] D Loss: 0.0025 G Loss: 2387246.5000
# GAN Epoch [25/50] Batch [20/125] D Loss: 0.0033 G Loss: 1402247.8750
# GAN Epoch [25/50] Batch [30/125] D Loss: 0.0028 G Loss: 532753.0625
# GAN Epoch [25/50] Batch [40/125] D Loss: 0.0036 G Loss: 91528.5312
# GAN Epoch [25/50] Batch [50/125] D Loss: 0.0023 G Loss: 1408622.7500
# GAN Epoch [25/50] Batch [60/125] D Loss: 0.0027 G Loss: 1215866.0000
# GAN Epoch [25/50] Batch [70/125] D Loss: 0.0290 G Loss: 384977.5938
# GAN Epoch [25/50] Batch [80/125] D Loss: 0.0279 G Loss: 268082.7188
# GAN Epoch [25/50] Batch [90/125] D Loss: 0.0121 G Loss: 165485.1094
# GAN Epoch [25/50] Batch [100/125] D Loss: 0.0088 G Loss: 731821.9375
# GAN Epoch [25/50] Batch [110/125] D Loss: 0.0083 G Loss: 700118.3125
# GAN Epoch [25/50] Batch [120/125] D Loss: 0.0057 G Loss: 494536.6562
# GAN Epoch [25/50], Average Generator Loss: 721845.7445
# GAN Epoch [26/50] Batch [0/125] D Loss: 0.0057 G Loss: 1199352.7500
# GAN Epoch [26/50] Batch [10/125] D Loss: 0.0056 G Loss: 2482827.7500
# GAN Epoch [26/50] Batch [20/125] D Loss: 0.0079 G Loss: 2706959.0000
# GAN Epoch [26/50] Batch [30/125] D Loss: 0.0079 G Loss: 568456.3125
# GAN Epoch [26/50] Batch [40/125] D Loss: 0.0050 G Loss: 190802.7500
# GAN Epoch [26/50] Batch [50/125] D Loss: 0.0036 G Loss: 693759.8125
# GAN Epoch [26/50] Batch [60/125] D Loss: 0.0036 G Loss: 417899.6875
# GAN Epoch [26/50] Batch [70/125] D Loss: 0.0055 G Loss: 258546.1875
# GAN Epoch [26/50] Batch [80/125] D Loss: 0.0111 G Loss: 80156.8516
# GAN Epoch [26/50] Batch [90/125] D Loss: 0.0042 G Loss: 219715.6562
# GAN Epoch [26/50] Batch [100/125] D Loss: 0.0040 G Loss: 635010.8750
# GAN Epoch [26/50] Batch [110/125] D Loss: 0.0030 G Loss: 1205504.7500
# GAN Epoch [26/50] Batch [120/125] D Loss: 0.0042 G Loss: 152129.2344
# Saved best generator model at epoch 26 with average G Loss 720395.8184
# GAN Epoch [26/50], Average Generator Loss: 720395.8184
# GAN Epoch [27/50] Batch [0/125] D Loss: 0.0035 G Loss: 295916.7812
# GAN Epoch [27/50] Batch [10/125] D Loss: 0.0031 G Loss: 94436.1328
# GAN Epoch [27/50] Batch [20/125] D Loss: 0.0033 G Loss: 490712.5312
# GAN Epoch [27/50] Batch [30/125] D Loss: 0.0033 G Loss: 115615.0938
# GAN Epoch [27/50] Batch [40/125] D Loss: 0.0039 G Loss: 263383.3125
# GAN Epoch [27/50] Batch [50/125] D Loss: 0.0069 G Loss: 74951.8438
# GAN Epoch [27/50] Batch [60/125] D Loss: 0.0034 G Loss: 98233.4609
# GAN Epoch [27/50] Batch [70/125] D Loss: 0.0040 G Loss: 880846.0625
# GAN Epoch [27/50] Batch [80/125] D Loss: 0.0032 G Loss: 1349463.0000
# GAN Epoch [27/50] Batch [90/125] D Loss: 0.0024 G Loss: 817813.2500
# GAN Epoch [27/50] Batch [100/125] D Loss: 0.0025 G Loss: 514077.1562
# GAN Epoch [27/50] Batch [110/125] D Loss: 0.0023 G Loss: 318791.8750
# GAN Epoch [27/50] Batch [120/125] D Loss: 0.0028 G Loss: 444219.7812
# Saved best generator model at epoch 27 with average G Loss 719653.7667
# GAN Epoch [27/50], Average Generator Loss: 719653.7667
# GAN Epoch [28/50] Batch [0/125] D Loss: 0.0029 G Loss: 441669.5312
# GAN Epoch [28/50] Batch [10/125] D Loss: 0.0023 G Loss: 901743.7500
# GAN Epoch [28/50] Batch [20/125] D Loss: 0.0021 G Loss: 769035.7500
# GAN Epoch [28/50] Batch [30/125] D Loss: 0.0041 G Loss: 90973.7656
# GAN Epoch [28/50] Batch [40/125] D Loss: 0.0020 G Loss: 1230219.6250
# GAN Epoch [28/50] Batch [50/125] D Loss: 0.0023 G Loss: 1767495.6250
# GAN Epoch [28/50] Batch [60/125] D Loss: 0.0015 G Loss: 483464.5312
# GAN Epoch [28/50] Batch [70/125] D Loss: 0.0016 G Loss: 634624.4375
# GAN Epoch [28/50] Batch [80/125] D Loss: 0.0027 G Loss: 778283.8750
# GAN Epoch [28/50] Batch [90/125] D Loss: 0.0027 G Loss: 203745.1562
# GAN Epoch [28/50] Batch [100/125] D Loss: 0.0013 G Loss: 1234403.3750
# GAN Epoch [28/50] Batch [110/125] D Loss: 0.0020 G Loss: 2204844.7500
# GAN Epoch [28/50] Batch [120/125] D Loss: 0.0016 G Loss: 473387.4688
# GAN Epoch [28/50], Average Generator Loss: 720338.8149
# GAN Epoch [29/50] Batch [0/125] D Loss: 0.0019 G Loss: 785194.5625
# GAN Epoch [29/50] Batch [10/125] D Loss: 0.0026 G Loss: 1258152.3750
# GAN Epoch [29/50] Batch [20/125] D Loss: 0.0035 G Loss: 160036.0781
# GAN Epoch [29/50] Batch [30/125] D Loss: 0.0022 G Loss: 598116.6875
# GAN Epoch [29/50] Batch [40/125] D Loss: 0.0018 G Loss: 1460564.2500
# GAN Epoch [29/50] Batch [50/125] D Loss: 0.0021 G Loss: 778993.8125
# GAN Epoch [29/50] Batch [60/125] D Loss: 0.0021 G Loss: 250487.7500
# GAN Epoch [29/50] Batch [70/125] D Loss: 0.0016 G Loss: 362083.2188
# GAN Epoch [29/50] Batch [80/125] D Loss: 0.0017 G Loss: 523150.7812
# GAN Epoch [29/50] Batch [90/125] D Loss: 0.0025 G Loss: 210993.9844
# GAN Epoch [29/50] Batch [100/125] D Loss: 0.0013 G Loss: 872377.0000
# GAN Epoch [29/50] Batch [110/125] D Loss: 0.0025 G Loss: 60150.2773
# GAN Epoch [29/50] Batch [120/125] D Loss: 0.0017 G Loss: 1012790.6250
# Saved best generator model at epoch 29 with average G Loss 717439.6264
# GAN Epoch [29/50], Average Generator Loss: 717439.6264
# GAN Epoch [30/50] Batch [0/125] D Loss: 0.0015 G Loss: 388650.5938
# GAN Epoch [30/50] Batch [10/125] D Loss: 0.0018 G Loss: 122104.1875
# GAN Epoch [30/50] Batch [20/125] D Loss: 0.0039 G Loss: 817534.6250
# GAN Epoch [30/50] Batch [30/125] D Loss: 0.0017 G Loss: 158374.4062
# GAN Epoch [30/50] Batch [40/125] D Loss: 0.0015 G Loss: 1051698.2500
# GAN Epoch [30/50] Batch [50/125] D Loss: 0.0027 G Loss: 103876.8438
# GAN Epoch [30/50] Batch [60/125] D Loss: 0.0017 G Loss: 431017.9688
# GAN Epoch [30/50] Batch [70/125] D Loss: 0.0022 G Loss: 1561205.7500
# GAN Epoch [30/50] Batch [80/125] D Loss: 0.0017 G Loss: 415010.3125
# GAN Epoch [30/50] Batch [90/125] D Loss: 0.0013 G Loss: 707140.3125
# GAN Epoch [30/50] Batch [100/125] D Loss: 0.0016 G Loss: 45858.7305
# GAN Epoch [30/50] Batch [110/125] D Loss: 0.0021 G Loss: 355742.6875
# GAN Epoch [30/50] Batch [120/125] D Loss: 0.0012 G Loss: 1690723.1250
# Saved best generator model at epoch 30 with average G Loss 716950.1289
# GAN Epoch [30/50], Average Generator Loss: 716950.1289
# GAN Epoch [31/50] Batch [0/125] D Loss: 0.0010 G Loss: 73312.8281
# GAN Epoch [31/50] Batch [10/125] D Loss: 0.0011 G Loss: 346979.1562
# GAN Epoch [31/50] Batch [20/125] D Loss: 0.0016 G Loss: 832781.0625
# GAN Epoch [31/50] Batch [30/125] D Loss: 0.0012 G Loss: 432169.9688
# GAN Epoch [31/50] Batch [40/125] D Loss: 0.0015 G Loss: 2645015.2500
# GAN Epoch [31/50] Batch [50/125] D Loss: 0.0021 G Loss: 288524.7500
# GAN Epoch [31/50] Batch [60/125] D Loss: 0.0019 G Loss: 1166618.8750
# GAN Epoch [31/50] Batch [70/125] D Loss: 0.0021 G Loss: 560917.1250
# GAN Epoch [31/50] Batch [80/125] D Loss: 0.0009 G Loss: 655856.8750
# GAN Epoch [31/50] Batch [90/125] D Loss: 0.0009 G Loss: 2194219.2500
# GAN Epoch [31/50] Batch [100/125] D Loss: 0.0012 G Loss: 617878.7500
# GAN Epoch [31/50] Batch [110/125] D Loss: 0.0012 G Loss: 2191096.0000
# GAN Epoch [31/50] Batch [120/125] D Loss: 0.0018 G Loss: 99213.2578
# Saved best generator model at epoch 31 with average G Loss 714749.3425
# GAN Epoch [31/50], Average Generator Loss: 714749.3425
# GAN Epoch [32/50] Batch [0/125] D Loss: 0.0014 G Loss: 523028.0312
# GAN Epoch [32/50] Batch [10/125] D Loss: 0.0017 G Loss: 285648.1250
# GAN Epoch [32/50] Batch [20/125] D Loss: 0.0011 G Loss: 478201.9062
# GAN Epoch [32/50] Batch [30/125] D Loss: 0.0009 G Loss: 1010176.6875
# GAN Epoch [32/50] Batch [40/125] D Loss: 0.0016 G Loss: 691987.1875
# GAN Epoch [32/50] Batch [50/125] D Loss: 0.0019 G Loss: 527355.5000
# GAN Epoch [32/50] Batch [60/125] D Loss: 0.0011 G Loss: 2161119.2500
# GAN Epoch [32/50] Batch [70/125] D Loss: 0.0010 G Loss: 1476476.0000
# GAN Epoch [32/50] Batch [80/125] D Loss: 0.0008 G Loss: 750893.7500
# GAN Epoch [32/50] Batch [90/125] D Loss: 0.0016 G Loss: 107662.7734
# GAN Epoch [32/50] Batch [100/125] D Loss: 0.0018 G Loss: 331627.5938
# GAN Epoch [32/50] Batch [110/125] D Loss: 0.0011 G Loss: 896746.5625
# GAN Epoch [32/50] Batch [120/125] D Loss: 0.0010 G Loss: 672805.5000
# Saved best generator model at epoch 32 with average G Loss 714030.7957
# GAN Epoch [32/50], Average Generator Loss: 714030.7957
# GAN Epoch [33/50] Batch [0/125] D Loss: 0.0019 G Loss: 1024262.3750
# GAN Epoch [33/50] Batch [10/125] D Loss: 0.0017 G Loss: 121334.0859
# GAN Epoch [33/50] Batch [20/125] D Loss: 0.0019 G Loss: 1777179.5000
# GAN Epoch [33/50] Batch [30/125] D Loss: 0.0018 G Loss: 311757.7188
# GAN Epoch [33/50] Batch [40/125] D Loss: 0.0010 G Loss: 555875.4375
# GAN Epoch [33/50] Batch [50/125] D Loss: 0.0013 G Loss: 683503.3125
# GAN Epoch [33/50] Batch [60/125] D Loss: 0.0010 G Loss: 486513.8750
# GAN Epoch [33/50] Batch [70/125] D Loss: 0.0012 G Loss: 302292.1562
# GAN Epoch [33/50] Batch [80/125] D Loss: 0.0010 G Loss: 1257979.6250
# GAN Epoch [33/50] Batch [90/125] D Loss: 0.0012 G Loss: 516061.1562
# GAN Epoch [33/50] Batch [100/125] D Loss: 0.0008 G Loss: 474992.4062
# GAN Epoch [33/50] Batch [110/125] D Loss: 0.0012 G Loss: 142579.3750
# GAN Epoch [33/50] Batch [120/125] D Loss: 0.0009 G Loss: 1199035.3750
# Saved best generator model at epoch 33 with average G Loss 713178.1094
# GAN Epoch [33/50], Average Generator Loss: 713178.1094
# GAN Epoch [34/50] Batch [0/125] D Loss: 0.0013 G Loss: 1228815.0000
# GAN Epoch [34/50] Batch [10/125] D Loss: 0.0013 G Loss: 1132984.1250
# GAN Epoch [34/50] Batch [20/125] D Loss: 0.0010 G Loss: 1365553.2500
# GAN Epoch [34/50] Batch [30/125] D Loss: 0.0009 G Loss: 737249.5000
# GAN Epoch [34/50] Batch [40/125] D Loss: 0.0008 G Loss: 1747204.6250
# GAN Epoch [34/50] Batch [50/125] D Loss: 0.0012 G Loss: 898278.0625
# GAN Epoch [34/50] Batch [60/125] D Loss: 0.0012 G Loss: 223870.6250
# GAN Epoch [34/50] Batch [70/125] D Loss: 0.0013 G Loss: 289707.5625
# GAN Epoch [34/50] Batch [80/125] D Loss: 0.0010 G Loss: 225173.6094
# GAN Epoch [34/50] Batch [90/125] D Loss: 0.0012 G Loss: 210228.5938
# GAN Epoch [34/50] Batch [100/125] D Loss: 0.0011 G Loss: 717780.5000
# GAN Epoch [34/50] Batch [110/125] D Loss: 0.0008 G Loss: 188787.6875
# GAN Epoch [34/50] Batch [120/125] D Loss: 0.0010 G Loss: 1298836.3750
# GAN Epoch [34/50], Average Generator Loss: 713932.8203
# GAN Epoch [35/50] Batch [0/125] D Loss: 0.0011 G Loss: 699966.3125
# GAN Epoch [35/50] Batch [10/125] D Loss: 0.0009 G Loss: 541697.5000
# GAN Epoch [35/50] Batch [20/125] D Loss: 0.0006 G Loss: 941140.8750
# GAN Epoch [35/50] Batch [30/125] D Loss: 0.0014 G Loss: 82467.2109
# GAN Epoch [35/50] Batch [40/125] D Loss: 0.0012 G Loss: 326849.4062
# GAN Epoch [35/50] Batch [50/125] D Loss: 0.0010 G Loss: 213483.5000
# GAN Epoch [35/50] Batch [60/125] D Loss: 0.0008 G Loss: 1703828.1250
# GAN Epoch [35/50] Batch [70/125] D Loss: 0.0006 G Loss: 856270.7500
# GAN Epoch [35/50] Batch [80/125] D Loss: 0.0008 G Loss: 109643.5703
# GAN Epoch [35/50] Batch [90/125] D Loss: 0.0011 G Loss: 414587.6875
# GAN Epoch [35/50] Batch [100/125] D Loss: 0.0013 G Loss: 970483.6250
# GAN Epoch [35/50] Batch [110/125] D Loss: 0.0023 G Loss: 204911.8750
# GAN Epoch [35/50] Batch [120/125] D Loss: 0.0008 G Loss: 3130786.7500
# Saved best generator model at epoch 35 with average G Loss 712133.6508
# GAN Epoch [35/50], Average Generator Loss: 712133.6508
# GAN Epoch [36/50] Batch [0/125] D Loss: 0.0006 G Loss: 1135194.7500
# GAN Epoch [36/50] Batch [10/125] D Loss: 0.0008 G Loss: 743648.5625
# GAN Epoch [36/50] Batch [20/125] D Loss: 0.0006 G Loss: 2743077.5000
# GAN Epoch [36/50] Batch [30/125] D Loss: 0.0009 G Loss: 428034.8438
# GAN Epoch [36/50] Batch [40/125] D Loss: 0.0007 G Loss: 165310.6250
# GAN Epoch [36/50] Batch [50/125] D Loss: 0.0010 G Loss: 1914055.2500
# GAN Epoch [36/50] Batch [60/125] D Loss: 0.0008 G Loss: 385629.2188
# GAN Epoch [36/50] Batch [70/125] D Loss: 0.0008 G Loss: 1053103.6250
# GAN Epoch [36/50] Batch [80/125] D Loss: 0.0005 G Loss: 1091278.6250
# GAN Epoch [36/50] Batch [90/125] D Loss: 0.0006 G Loss: 1926202.6250
# GAN Epoch [36/50] Batch [100/125] D Loss: 0.0009 G Loss: 623764.5000
# GAN Epoch [36/50] Batch [110/125] D Loss: 0.0010 G Loss: 337823.2188
# GAN Epoch [36/50] Batch [120/125] D Loss: 0.0006 G Loss: 1216464.6250
# GAN Epoch [36/50], Average Generator Loss: 712648.2921
# GAN Epoch [37/50] Batch [0/125] D Loss: 0.0007 G Loss: 183879.9062
# GAN Epoch [37/50] Batch [10/125] D Loss: 0.0007 G Loss: 433386.3125
# GAN Epoch [37/50] Batch [20/125] D Loss: 0.0005 G Loss: 228224.7031
# GAN Epoch [37/50] Batch [30/125] D Loss: 0.0007 G Loss: 1212846.6250
# GAN Epoch [37/50] Batch [40/125] D Loss: 0.0005 G Loss: 1566288.7500
# GAN Epoch [37/50] Batch [50/125] D Loss: 0.0013 G Loss: 1499212.1250
# GAN Epoch [37/50] Batch [60/125] D Loss: 0.0009 G Loss: 457366.5000
# GAN Epoch [37/50] Batch [70/125] D Loss: 0.0012 G Loss: 473332.1250
# GAN Epoch [37/50] Batch [80/125] D Loss: 0.0005 G Loss: 779641.0000
# GAN Epoch [37/50] Batch [90/125] D Loss: 0.0009 G Loss: 126278.4375
# GAN Epoch [37/50] Batch [100/125] D Loss: 0.0005 G Loss: 1798717.5000
# GAN Epoch [37/50] Batch [110/125] D Loss: 0.0009 G Loss: 211335.5156
# GAN Epoch [37/50] Batch [120/125] D Loss: 0.0005 G Loss: 761262.5000
# Saved best generator model at epoch 37 with average G Loss 710201.5525
# GAN Epoch [37/50], Average Generator Loss: 710201.5525
# GAN Epoch [38/50] Batch [0/125] D Loss: 0.0007 G Loss: 389006.1875
# GAN Epoch [38/50] Batch [10/125] D Loss: 0.0006 G Loss: 682310.6250
# GAN Epoch [38/50] Batch [20/125] D Loss: 0.0007 G Loss: 683657.5000
# GAN Epoch [38/50] Batch [30/125] D Loss: 0.0006 G Loss: 467715.9375
# GAN Epoch [38/50] Batch [40/125] D Loss: 0.0008 G Loss: 684438.2500
# GAN Epoch [38/50] Batch [50/125] D Loss: 0.0007 G Loss: 306894.4688
# GAN Epoch [38/50] Batch [60/125] D Loss: 0.0008 G Loss: 563396.3125
# GAN Epoch [38/50] Batch [70/125] D Loss: 0.0008 G Loss: 439421.8750
# GAN Epoch [38/50] Batch [80/125] D Loss: 0.0009 G Loss: 521187.5938
# GAN Epoch [38/50] Batch [90/125] D Loss: 0.0007 G Loss: 202284.4844
# GAN Epoch [38/50] Batch [100/125] D Loss: 0.0005 G Loss: 880547.7500
# GAN Epoch [38/50] Batch [110/125] D Loss: 0.0010 G Loss: 481223.5938
# GAN Epoch [38/50] Batch [120/125] D Loss: 0.0008 G Loss: 2852175.2500
# Saved best generator model at epoch 38 with average G Loss 709359.9798
# GAN Epoch [38/50], Average Generator Loss: 709359.9798
# GAN Epoch [39/50] Batch [0/125] D Loss: 0.0019 G Loss: 203522.2031
# GAN Epoch [39/50] Batch [10/125] D Loss: 0.0010 G Loss: 911500.7500
# GAN Epoch [39/50] Batch [20/125] D Loss: 0.0006 G Loss: 2996811.7500
# GAN Epoch [39/50] Batch [30/125] D Loss: 0.0007 G Loss: 569854.6250
# GAN Epoch [39/50] Batch [40/125] D Loss: 0.0007 G Loss: 807248.0625
# GAN Epoch [39/50] Batch [50/125] D Loss: 0.0006 G Loss: 426453.4688
# GAN Epoch [39/50] Batch [60/125] D Loss: 0.0008 G Loss: 134995.5156
# GAN Epoch [39/50] Batch [70/125] D Loss: 0.0013 G Loss: 168904.5000
# GAN Epoch [39/50] Batch [80/125] D Loss: 0.0007 G Loss: 366679.8125
# GAN Epoch [39/50] Batch [90/125] D Loss: 0.0005 G Loss: 2491977.5000
# GAN Epoch [39/50] Batch [100/125] D Loss: 0.0006 G Loss: 314788.7812
# GAN Epoch [39/50] Batch [110/125] D Loss: 0.0009 G Loss: 275015.9375
# GAN Epoch [39/50] Batch [120/125] D Loss: 0.0005 G Loss: 429257.9062
# Saved best generator model at epoch 39 with average G Loss 707850.5804
# GAN Epoch [39/50], Average Generator Loss: 707850.5804
# GAN Epoch [40/50] Batch [0/125] D Loss: 0.0005 G Loss: 366361.2500
# GAN Epoch [40/50] Batch [10/125] D Loss: 0.0010 G Loss: 190718.5938
# GAN Epoch [40/50] Batch [20/125] D Loss: 0.0005 G Loss: 592220.1875
# GAN Epoch [40/50] Batch [30/125] D Loss: 0.0007 G Loss: 690094.1875
# GAN Epoch [40/50] Batch [40/125] D Loss: 0.0007 G Loss: 93287.9531
# GAN Epoch [40/50] Batch [50/125] D Loss: 0.0005 G Loss: 142652.5156
# GAN Epoch [40/50] Batch [60/125] D Loss: 0.0005 G Loss: 128961.2500
# GAN Epoch [40/50] Batch [70/125] D Loss: 0.0007 G Loss: 476859.2812
# GAN Epoch [40/50] Batch [80/125] D Loss: 0.0005 G Loss: 1423600.2500
# GAN Epoch [40/50] Batch [90/125] D Loss: 0.0006 G Loss: 1637573.1250
# GAN Epoch [40/50] Batch [100/125] D Loss: 0.0010 G Loss: 285690.9062
# GAN Epoch [40/50] Batch [110/125] D Loss: 0.0004 G Loss: 1796460.7500
# GAN Epoch [40/50] Batch [120/125] D Loss: 0.0006 G Loss: 145570.3281
# GAN Epoch [40/50], Average Generator Loss: 709808.9436
# GAN Epoch [41/50] Batch [0/125] D Loss: 0.0011 G Loss: 45519.4727
# GAN Epoch [41/50] Batch [10/125] D Loss: 0.0008 G Loss: 239201.5156
# GAN Epoch [41/50] Batch [20/125] D Loss: 0.0008 G Loss: 238279.9688
# GAN Epoch [41/50] Batch [30/125] D Loss: 0.0004 G Loss: 1373655.1250
# GAN Epoch [41/50] Batch [40/125] D Loss: 0.0005 G Loss: 677401.7500
# GAN Epoch [41/50] Batch [50/125] D Loss: 0.0006 G Loss: 926137.6250
# GAN Epoch [41/50] Batch [60/125] D Loss: 0.0010 G Loss: 577855.3750
# GAN Epoch [41/50] Batch [70/125] D Loss: 0.0004 G Loss: 1487796.0000
# GAN Epoch [41/50] Batch [80/125] D Loss: 0.0005 G Loss: 161169.6250
# GAN Epoch [41/50] Batch [90/125] D Loss: 0.0004 G Loss: 1606879.8750
# GAN Epoch [41/50] Batch [100/125] D Loss: 0.0005 G Loss: 253578.0625
# GAN Epoch [41/50] Batch [110/125] D Loss: 0.0009 G Loss: 77567.8125
# GAN Epoch [41/50] Batch [120/125] D Loss: 0.0004 G Loss: 787852.5000
# GAN Epoch [41/50], Average Generator Loss: 708062.6455
# GAN Epoch [42/50] Batch [0/125] D Loss: 0.0004 G Loss: 693683.0000
# GAN Epoch [42/50] Batch [10/125] D Loss: 0.0010 G Loss: 459536.2188
# GAN Epoch [42/50] Batch [20/125] D Loss: 0.0010 G Loss: 236022.0625
# GAN Epoch [42/50] Batch [30/125] D Loss: 0.0004 G Loss: 408876.7188
# GAN Epoch [42/50] Batch [40/125] D Loss: 0.0004 G Loss: 731673.2500
# GAN Epoch [42/50] Batch [50/125] D Loss: 0.0005 G Loss: 1566473.0000
# GAN Epoch [42/50] Batch [60/125] D Loss: 0.0005 G Loss: 286567.8750
# GAN Epoch [42/50] Batch [70/125] D Loss: 0.0004 G Loss: 1392761.6250
# GAN Epoch [42/50] Batch [80/125] D Loss: 0.0003 G Loss: 1424759.2500
# GAN Epoch [42/50] Batch [90/125] D Loss: 0.0005 G Loss: 502897.7500
# GAN Epoch [42/50] Batch [100/125] D Loss: 0.0004 G Loss: 623231.5625
# GAN Epoch [42/50] Batch [110/125] D Loss: 0.0006 G Loss: 252437.6719
# GAN Epoch [42/50] Batch [120/125] D Loss: 0.0007 G Loss: 286814.4062
# Saved best generator model at epoch 42 with average G Loss 705911.7970
# GAN Epoch [42/50], Average Generator Loss: 705911.7970
# GAN Epoch [43/50] Batch [0/125] D Loss: 0.0004 G Loss: 90416.6562
# GAN Epoch [43/50] Batch [10/125] D Loss: 0.0004 G Loss: 5109304.0000
# GAN Epoch [43/50] Batch [20/125] D Loss: 0.0003 G Loss: 606921.3125
# GAN Epoch [43/50] Batch [30/125] D Loss: 0.0006 G Loss: 116414.7734
# GAN Epoch [43/50] Batch [40/125] D Loss: 0.0005 G Loss: 164019.6250
# GAN Epoch [43/50] Batch [50/125] D Loss: 0.0004 G Loss: 818897.9375
# GAN Epoch [43/50] Batch [60/125] D Loss: 0.0004 G Loss: 1730003.6250
# GAN Epoch [43/50] Batch [70/125] D Loss: 0.0004 G Loss: 2486569.0000
# GAN Epoch [43/50] Batch [80/125] D Loss: 0.0003 G Loss: 1533843.0000
# GAN Epoch [43/50] Batch [90/125] D Loss: 0.0004 G Loss: 413463.4688
# GAN Epoch [43/50] Batch [100/125] D Loss: 0.0010 G Loss: 140539.3438
# GAN Epoch [43/50] Batch [110/125] D Loss: 0.0005 G Loss: 563593.1250
# GAN Epoch [43/50] Batch [120/125] D Loss: 0.0004 G Loss: 236965.4844
# Saved best generator model at epoch 43 with average G Loss 704376.2111
# GAN Epoch [43/50], Average Generator Loss: 704376.2111
# GAN Epoch [44/50] Batch [0/125] D Loss: 0.0005 G Loss: 104832.0625
# GAN Epoch [44/50] Batch [10/125] D Loss: 0.0004 G Loss: 194247.8906
# GAN Epoch [44/50] Batch [20/125] D Loss: 0.0003 G Loss: 334332.9062
# GAN Epoch [44/50] Batch [30/125] D Loss: 0.0004 G Loss: 2062419.8750
# GAN Epoch [44/50] Batch [40/125] D Loss: 0.0005 G Loss: 243743.4688
# GAN Epoch [44/50] Batch [50/125] D Loss: 0.0004 G Loss: 931957.8750
# GAN Epoch [44/50] Batch [60/125] D Loss: 0.0005 G Loss: 219185.3594
# GAN Epoch [44/50] Batch [70/125] D Loss: 0.0005 G Loss: 421918.2812
# GAN Epoch [44/50] Batch [80/125] D Loss: 0.0006 G Loss: 1669388.2500
# GAN Epoch [44/50] Batch [90/125] D Loss: 0.0007 G Loss: 269686.0312
# GAN Epoch [44/50] Batch [100/125] D Loss: 0.0004 G Loss: 530006.3750
# GAN Epoch [44/50] Batch [110/125] D Loss: 0.0005 G Loss: 86497.2969
# GAN Epoch [44/50] Batch [120/125] D Loss: 0.0007 G Loss: 101127.9688
# Saved best generator model at epoch 44 with average G Loss 703376.3011
# GAN Epoch [44/50], Average Generator Loss: 703376.3011
# GAN Epoch [45/50] Batch [0/125] D Loss: 0.0004 G Loss: 1994926.8750
# GAN Epoch [45/50] Batch [10/125] D Loss: 0.0005 G Loss: 223299.0781
# GAN Epoch [45/50] Batch [20/125] D Loss: 0.0003 G Loss: 1201596.5000
# GAN Epoch [45/50] Batch [30/125] D Loss: 0.0004 G Loss: 313453.3438
# GAN Epoch [45/50] Batch [40/125] D Loss: 0.0005 G Loss: 203932.4062
# GAN Epoch [45/50] Batch [50/125] D Loss: 0.0005 G Loss: 342231.6562
# GAN Epoch [45/50] Batch [60/125] D Loss: 0.0006 G Loss: 317563.7500
# GAN Epoch [45/50] Batch [70/125] D Loss: 0.0004 G Loss: 343069.1875
# GAN Epoch [45/50] Batch [80/125] D Loss: 0.0004 G Loss: 429580.6250
# GAN Epoch [45/50] Batch [90/125] D Loss: 0.0004 G Loss: 456303.3438
# GAN Epoch [45/50] Batch [100/125] D Loss: 0.0003 G Loss: 213429.7656
# GAN Epoch [45/50] Batch [110/125] D Loss: 0.0004 G Loss: 158404.0469
# GAN Epoch [45/50] Batch [120/125] D Loss: 0.0003 G Loss: 1242355.5000
# Saved best generator model at epoch 45 with average G Loss 702859.3382
# GAN Epoch [45/50], Average Generator Loss: 702859.3382
# GAN Epoch [46/50] Batch [0/125] D Loss: 0.0004 G Loss: 367622.8438
# GAN Epoch [46/50] Batch [10/125] D Loss: 0.0003 G Loss: 2267584.0000
# GAN Epoch [46/50] Batch [20/125] D Loss: 0.0003 G Loss: 251126.7344
# GAN Epoch [46/50] Batch [30/125] D Loss: 0.0003 G Loss: 799421.0625
# GAN Epoch [46/50] Batch [40/125] D Loss: 0.0003 G Loss: 964833.6875
# GAN Epoch [46/50] Batch [50/125] D Loss: 0.0003 G Loss: 329632.9062
# GAN Epoch [46/50] Batch [60/125] D Loss: 0.0004 G Loss: 401235.1562
# GAN Epoch [46/50] Batch [70/125] D Loss: 0.0003 G Loss: 1010063.2500
# GAN Epoch [46/50] Batch [80/125] D Loss: 0.0004 G Loss: 1004944.3750
# GAN Epoch [46/50] Batch [90/125] D Loss: 0.0004 G Loss: 321676.0625
# GAN Epoch [46/50] Batch [100/125] D Loss: 0.0004 G Loss: 331444.6562
# GAN Epoch [46/50] Batch [110/125] D Loss: 0.0028 G Loss: 132313.6250
# GAN Epoch [46/50] Batch [120/125] D Loss: 0.0021 G Loss: 418740.2500
# Saved best generator model at epoch 46 with average G Loss 702154.3279
# GAN Epoch [46/50], Average Generator Loss: 702154.3279
# GAN Epoch [47/50] Batch [0/125] D Loss: 0.0006 G Loss: 606231.3125
# GAN Epoch [47/50] Batch [10/125] D Loss: 0.0006 G Loss: 2897118.5000
# GAN Epoch [47/50] Batch [20/125] D Loss: 0.0005 G Loss: 1439503.6250
# GAN Epoch [47/50] Batch [30/125] D Loss: 0.0005 G Loss: 1476832.2500
# GAN Epoch [47/50] Batch [40/125] D Loss: 0.0003 G Loss: 844934.8750
# GAN Epoch [47/50] Batch [50/125] D Loss: 0.0004 G Loss: 1715557.2500
# GAN Epoch [47/50] Batch [60/125] D Loss: 0.0005 G Loss: 282108.3750
# GAN Epoch [47/50] Batch [70/125] D Loss: 0.0006 G Loss: 162712.1406
# GAN Epoch [47/50] Batch [80/125] D Loss: 0.0004 G Loss: 247111.1406
# GAN Epoch [47/50] Batch [90/125] D Loss: 0.0005 G Loss: 317666.7188
# GAN Epoch [47/50] Batch [100/125] D Loss: 0.0005 G Loss: 266744.0625
# GAN Epoch [47/50] Batch [110/125] D Loss: 0.0005 G Loss: 305493.7500
# GAN Epoch [47/50] Batch [120/125] D Loss: 0.0004 G Loss: 382766.1250
# Saved best generator model at epoch 47 with average G Loss 702126.0949
# GAN Epoch [47/50], Average Generator Loss: 702126.0949
# GAN Epoch [48/50] Batch [0/125] D Loss: 0.0004 G Loss: 766597.1250
# GAN Epoch [48/50] Batch [10/125] D Loss: 0.0003 G Loss: 508431.2812
# GAN Epoch [48/50] Batch [20/125] D Loss: 0.0004 G Loss: 744815.3125
# GAN Epoch [48/50] Batch [30/125] D Loss: 0.0003 G Loss: 1475478.3750
# GAN Epoch [48/50] Batch [40/125] D Loss: 0.0005 G Loss: 1060930.3750
# GAN Epoch [48/50] Batch [50/125] D Loss: 0.0007 G Loss: 406705.7188
# GAN Epoch [48/50] Batch [60/125] D Loss: 0.0005 G Loss: 259706.3438
# GAN Epoch [48/50] Batch [70/125] D Loss: 0.0004 G Loss: 127909.9766
# GAN Epoch [48/50] Batch [80/125] D Loss: 0.0003 G Loss: 526912.5000
# GAN Epoch [48/50] Batch [90/125] D Loss: 0.0002 G Loss: 2081628.8750
# GAN Epoch [48/50] Batch [100/125] D Loss: 0.0003 G Loss: 120840.0703
# GAN Epoch [48/50] Batch [110/125] D Loss: 0.0005 G Loss: 1922734.0000
# GAN Epoch [48/50] Batch [120/125] D Loss: 0.0003 G Loss: 731215.2500
# Saved best generator model at epoch 48 with average G Loss 699761.2791
# GAN Epoch [48/50], Average Generator Loss: 699761.2791
# GAN Epoch [49/50] Batch [0/125] D Loss: 0.0003 G Loss: 402857.6562
# GAN Epoch [49/50] Batch [10/125] D Loss: 0.0004 G Loss: 211184.9531
# GAN Epoch [49/50] Batch [20/125] D Loss: 0.0003 G Loss: 359364.0625
# GAN Epoch [49/50] Batch [30/125] D Loss: 0.0003 G Loss: 59022.8359
# GAN Epoch [49/50] Batch [40/125] D Loss: 0.0002 G Loss: 344615.8438
# GAN Epoch [49/50] Batch [50/125] D Loss: 0.0003 G Loss: 580215.5625
# GAN Epoch [49/50] Batch [60/125] D Loss: 0.0004 G Loss: 200088.5781
# GAN Epoch [49/50] Batch [70/125] D Loss: 0.0004 G Loss: 279876.8438
# GAN Epoch [49/50] Batch [80/125] D Loss: 0.0003 G Loss: 159885.7500
# GAN Epoch [49/50] Batch [90/125] D Loss: 0.0004 G Loss: 464345.4688
# GAN Epoch [49/50] Batch [100/125] D Loss: 0.0003 G Loss: 328987.9062
# GAN Epoch [49/50] Batch [110/125] D Loss: 0.0003 G Loss: 467690.7500
# GAN Epoch [49/50] Batch [120/125] D Loss: 0.0002 G Loss: 521347.3125
# Saved best generator model at epoch 49 with average G Loss 698875.9491
# GAN Epoch [49/50], Average Generator Loss: 698875.9491
# GAN Epoch [50/50] Batch [0/125] D Loss: 0.0002 G Loss: 1102470.3750
# GAN Epoch [50/50] Batch [10/125] D Loss: 0.0002 G Loss: 129833.8047
# GAN Epoch [50/50] Batch [20/125] D Loss: 0.0004 G Loss: 328296.0625
# GAN Epoch [50/50] Batch [30/125] D Loss: 0.0002 G Loss: 578457.0000
# GAN Epoch [50/50] Batch [40/125] D Loss: 0.0004 G Loss: 1089596.3750
# GAN Epoch [50/50] Batch [50/125] D Loss: 0.0002 G Loss: 891680.5000
# GAN Epoch [50/50] Batch [60/125] D Loss: 0.0002 G Loss: 384356.8125
# GAN Epoch [50/50] Batch [70/125] D Loss: 0.0004 G Loss: 463832.5000
# GAN Epoch [50/50] Batch [80/125] D Loss: 0.0003 G Loss: 223394.5938
# GAN Epoch [50/50] Batch [90/125] D Loss: 0.0003 G Loss: 317739.5938
# GAN Epoch [50/50] Batch [100/125] D Loss: 0.0002 G Loss: 1416513.3750
# GAN Epoch [50/50] Batch [110/125] D Loss: 0.0002 G Loss: 223943.9688
# GAN Epoch [50/50] Batch [120/125] D Loss: 0.0002 G Loss: 831240.5625
# Saved best generator model at epoch 50 with average G Loss 697843.7476
# GAN Epoch [50/50], Average Generator Loss: 697843.7476
# Training Complete!

# %%
# Genre conversion function
def convert_genre(audio_tensor, source_genre, target_genre):
    print(f"Converting from {source_genre} to {target_genre}...")
    audio_tensor = audio_tensor.to(device)
    converted_audio = generator(audio_tensor.unsqueeze(0)).squeeze(0)

    # Predict the genre of the converted audio
    predicted_genre_idx = predict_genre(converted_audio)
    predicted_genre = list(train_dataset.label_dict.keys())[predicted_genre_idx]

    print(f"Converted audio predicted as: {predicted_genre}")
    return converted_audio

# Genre prediction function
def predict_genre(audio_tensor):
    audio_tensor = audio_tensor.to(device)
    with torch.no_grad():
        prediction = classifier(audio_tensor.unsqueeze(0))
    return torch.argmax(prediction, dim=1).item()

def load_and_preprocess_audio(file_path, duration=3):
    """Load and preprocess an audio file for conversion.

    Args:
        file_path (str): Path to the input audio file.
        duration (int): Desired duration in seconds (default is 3 seconds).

    Returns:
        torch.Tensor: Mel-spectrogram tensor of shape [n_mels, time].
    """
    # Load audio file using librosa
    waveform, sr = librosa.load(file_path, sr=SAMPLE_RATE)

    # Trim or pad to desired duration
    if len(waveform) > SAMPLE_RATE * duration:
        waveform = waveform[:SAMPLE_RATE * duration]
    else:
        padding = SAMPLE_RATE * duration - len(waveform)
        waveform = np.pad(waveform, (0, padding), mode='constant')

    # Convert waveform to mel-spectrogram using torchaudio
    transform = transforms.MelSpectrogram(
        sample_rate=SAMPLE_RATE,
        n_mels=N_MELS,
        n_fft=N_FFT,
        hop_length=HOP_LENGTH
    )
    waveform_tensor = torch.tensor(waveform)
    mel_spec = transform(waveform_tensor).squeeze(0)  # Shape: [n_mels, time]

    return mel_spec

def convert_audio_file(input_path, output_path, source_genre, target_genre):
    """
    Convert an audio file from source_genre to target_genre and save the converted audio.

    Args:
        input_path (str): Path to the input audio file.
        output_path (str): Path to save the converted audio.
        source_genre (str): Name of the source genre (for logging).
        target_genre (str): Name of the target genre (for logging).
    """
    # Load and preprocess audio
    print(f"Loading and preprocessing {input_path}...")
    mel_spec = load_and_preprocess_audio(input_path)

    # Convert genre - ensure the generator is in evaluation mode
    generator.eval()
    with torch.no_grad():
        print(f"Converting from {source_genre} to {target_genre}...")
        converted_mel = convert_genre(mel_spec, source_genre, target_genre)

    # Convert mel-spectrogram back to audio using inverse transforms (Griffin-Lim)
    print("Converting back to waveform...")

    # Create inverse mel-scale transform
    inv_mel = transforms.InverseMelScale(
        n_stft=N_FFT // 2 + 1,
        n_mels=N_MELS,
        sample_rate=SAMPLE_RATE
    )

    # Create Griffin-Lim transform for spectrogram inversion
    griffin_lim = transforms.GriffinLim(
        n_fft=N_FFT,
        hop_length=HOP_LENGTH,
        n_iter=32
    )

    # Ensure proper shape: add batch dimension -> [1, n_mels, time]
    converted_mel = converted_mel.unsqueeze(0).detach().cpu()

    # Convert mel to linear spectrogram
    spec_estimate = inv_mel(converted_mel)

    # Reconstruct waveform from the spectrogram
    waveform = griffin_lim(spec_estimate)

    # Save the converted audio (waveform must be detached and on CPU)
    torchaudio.save(output_path, waveform.detach(), SAMPLE_RATE)
    print(f"Converted audio saved to {output_path}")

# Example usage:
if __name__ == "__main__":
    # Example file paths - replace these with your actual file paths
    input_audio = "/content/gtzan_dataset/genres_original/disco/disco.00000.wav"  # Your input audio file
    output_audio = "output_classical.wav"  # Where to save the converted audio

    # Ensure your train_dataset is defined globally and has been created during training.
    # This line prints the available genres in the dataset.
    available_genres = list(train_dataset.label_dict.keys())
    print("Available genres:", available_genres)

    # Example conversion: converting from 'metal' to 'rock'
    convert_audio_file(
        input_path=input_audio,
        output_path=output_audio,
        source_genre="disco",
        target_genre="classical"
    )
# Out:
# Available genres: ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# Loading and preprocessing /content/gtzan_dataset/genres_original/disco/disco.00000.wav...
# Converting from disco to classical...
# Converting from disco to classical...
# Converted audio predicted as: pop
# Converting back to waveform...
# Converted audio saved to output_classical.wav

# %% [markdown]
# Upar vala nhi chala neeche vala new version 1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchaudio
import torchaudio.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import librosa
import numpy as np
import os
from glob import glob
import matplotlib.pyplot as plt
from tqdm import tqdm

# Constants
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SAMPLE_RATE = 22050
N_MELS = 128
N_FFT = 2048
HOP_LENGTH = 512
BATCH_SIZE = 8
EPOCHS = 20
LEARNING_RATE = 2e-4
NUM_GENRES = 10  # For GTZAN dataset

# Dataset Class with fixed dimensions
class GTZANDataset(Dataset):
    def __init__(self, root_dir, duration=3):
        self.file_paths = glob(os.path.join(root_dir, "genres_original", "*", "*.wav"))
        if not self.file_paths:
            raise ValueError(f"No .wav files found in {root_dir}")

        self.labels = [os.path.basename(os.path.dirname(fp)) for fp in self.file_paths]
        self.label_dict = {genre: idx for idx, genre in enumerate(sorted(set(self.labels)))}
        self.duration = duration

        # Calculate exact time dimension
        self.time_dim = (duration * SAMPLE_RATE) // HOP_LENGTH + 1

        self.mel_transform = transforms.MelSpectrogram(
            sample_rate=SAMPLE_RATE,
            n_mels=N_MELS,
            n_fft=N_FFT,
            hop_length=HOP_LENGTH
        )

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        file_path = self.file_paths[idx]
        label = self.label_dict[self.labels[idx]]

        # Load with exact duration
        waveform, _ = librosa.load(file_path, sr=SAMPLE_RATE, duration=self.duration)
        if len(waveform) < SAMPLE_RATE * self.duration:
            padding = SAMPLE_RATE * self.duration - len(waveform)
            waveform = np.pad(waveform, (0, padding), mode='constant')

        waveform = torch.FloatTensor(waveform)
        mel_spec = self.mel_transform(waveform)

        # Ensure exact dimensions
        if mel_spec.shape[-1] > self.time_dim:
            mel_spec = mel_spec[..., :self.time_dim]
        elif mel_spec.shape[-1] < self.time_dim:
            padding = self.time_dim - mel_spec.shape[-1]
            mel_spec = F.pad(mel_spec, (0, padding))

        # Log scaling and normalization
        mel_spec = torch.log(mel_spec + 1e-9)
        mel_spec = (mel_spec - mel_spec.mean()) / (mel_spec.std() + 1e-9)

        return mel_spec, label

# Genre-Conditioned Generator with fixed dimensions
class GenreConditionedGenerator(nn.Module):
    def __init__(self, num_genres=NUM_GENRES):
        super().__init__()

        # Genre embedding
        self.genre_embedding = nn.Embedding(num_genres, 64)

        # Initial convolution
        self.initial = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=7, stride=1, padding=3),
            nn.InstanceNorm2d(64),
            nn.ReLU(inplace=True)
        )

        # Downsample blocks
        self.down1 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.InstanceNorm2d(128),
            nn.ReLU(inplace=True)
        )

        self.down2 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1),
            nn.InstanceNorm2d(256),
            nn.ReLU(inplace=True)
        )

        # Residual blocks with genre conditioning
        self.resblocks = nn.ModuleList([
            ResidualBlock(256, num_genres) for _ in range(6)
        ])

        # Upsample blocks with output padding
        self.up1 = nn.Sequential(
            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2,
                              padding=1, output_padding=1),
            nn.InstanceNorm2d(128),
            nn.ReLU(inplace=True)
        )

        self.up2 = nn.Sequential(
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2,
                              padding=1, output_padding=1),
            nn.InstanceNorm2d(64),
            nn.ReLU(inplace=True)
        )

        # Final convolution
        self.final = nn.Sequential(
            nn.Conv2d(64, 1, kernel_size=7, stride=1, padding=3),
            nn.Tanh()
        )

    def forward(self, x, target_genre):
        # Store original dimensions
        original_size = x.size()

        # Initial processing
        x = self.initial(x)

        # Downsample
        x = self.down1(x)
        x = self.down2(x)

        # Get genre embedding
        genre_emb = self.genre_embedding(target_genre)  # [B, 64]
        genre_emb = genre_emb.unsqueeze(-1).unsqueeze(-1)  # [B, 64, 1, 1]

        # Residual blocks
        for block in self.resblocks:
            x = block(x, genre_emb)

        # Upsample
        x = self.up1(x)
        x = self.up2(x)

        # Final processing
        x = self.final(x)

        # Ensure output matches input dimensions
        if x.size() != original_size:
            x = F.interpolate(x, size=original_size[2:], mode='bilinear', align_corners=False)

        return x

# Update the ResidualBlock class to fix the dimension mismatch
class ResidualBlock(nn.Module):
    def __init__(self, channels, num_genres):
        super().__init__()

        # Project genre embedding to match channel dimensions
        self.genre_proj = nn.Sequential(
            nn.Linear(64, channels),
            nn.ReLU(inplace=True)
        )

        self.conv1 = nn.Conv2d(channels, channels, kernel_size=3, padding=1)
        self.in1 = nn.InstanceNorm2d(channels)
        self.conv2 = nn.Conv2d(channels, channels, kernel_size=3, padding=1)
        self.in2 = nn.InstanceNorm2d(channels)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x, genre_emb):
        residual = x

        # Process genre embedding
        genre_emb = self.genre_proj(genre_emb.squeeze(-1).squeeze(-1))  # [B, C]
        genre_emb = genre_emb.view(genre_emb.size(0), genre_emb.size(1), 1, 1)
        genre_emb = genre_emb.expand(-1, -1, x.size(2), x.size(3))

        # Add genre conditioning
        x = x + genre_emb

        x = self.relu(self.in1(self.conv1(x)))
        x = self.in2(self.conv2(x))

        return x + residual

# Discriminator with Genre Classification
class GenreAwareDiscriminator(nn.Module):
    def __init__(self, num_genres=NUM_GENRES):
        super().__init__()

        self.model = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2),

            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(128),
            nn.LeakyReLU(0.2),

            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(256),
            nn.LeakyReLU(0.2),

            nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(512),
            nn.LeakyReLU(0.2),

            nn.AdaptiveAvgPool2d(1)
        )

        # Real/fake discriminator
        self.discriminator = nn.Linear(512, 1)

        # Genre classifier
        self.genre_classifier = nn.Linear(512, num_genres)

    def forward(self, x):
        features = self.model(x).squeeze(-1).squeeze(-1)
        validity = self.discriminator(features)
        genre = self.genre_classifier(features)
        return validity, genre

# Training function with dimension checks
def train():
    # Initialize dataset
    dataset = GTZANDataset("/content/gtzan_dataset")
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

    # Initialize models
    generator = GenreConditionedGenerator().to(device)
    discriminator = GenreAwareDiscriminator().to(device)

    # Loss functions
    adversarial_loss = nn.BCEWithLogitsLoss()
    genre_classification_loss = nn.CrossEntropyLoss()
    cycle_loss = nn.L1Loss()
    identity_loss = nn.L1Loss()

    # Optimizers
    g_optimizer = optim.Adam(generator.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))
    d_optimizer = optim.Adam(discriminator.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))

    for epoch in range(EPOCHS):
        for i, (real_imgs, real_genres) in enumerate(tqdm(dataloader)):
            real_imgs = real_imgs.unsqueeze(1).to(device)  # Add channel dim [B,1,M,T]
            real_genres = real_genres.to(device)

            # Random target genres different from source
            target_genres = torch.randint(0, NUM_GENRES, (real_imgs.size(0),)).to(device)
            target_genres = torch.where(target_genres == real_genres,
                                     (target_genres + 1) % NUM_GENRES,
                                     target_genres)

            # ---------------------
            #  Train Discriminator
            # ---------------------
            d_optimizer.zero_grad()

            # Generate fake images
            fake_imgs = generator(real_imgs, target_genres)

            # Real images
            real_validity, real_genre_pred = discriminator(real_imgs)
            d_real_loss = adversarial_loss(real_validity, torch.ones_like(real_validity))
            d_real_genre_loss = genre_classification_loss(real_genre_pred, real_genres)

            # Fake images
            fake_validity, _ = discriminator(fake_imgs.detach())
            d_fake_loss = adversarial_loss(fake_validity, torch.zeros_like(fake_validity))

            d_loss = d_real_loss + d_fake_loss + d_real_genre_loss
            d_loss.backward()
            d_optimizer.step()

            # -----------------
            #  Train Generator
            # -----------------
            g_optimizer.zero_grad()

            # Generate fake images and reconstruct
            fake_imgs = generator(real_imgs, target_genres)
            reconstructed_imgs = generator(fake_imgs, real_genres)

            # Adversarial and genre loss
            fake_validity, fake_genre_pred = discriminator(fake_imgs)
            g_adv_loss = adversarial_loss(fake_validity, torch.ones_like(fake_validity))
            g_genre_loss = genre_classification_loss(fake_genre_pred, target_genres)

            # Cycle consistency loss (with dimension check)
            if reconstructed_imgs.shape == real_imgs.shape:
                g_cycle_loss = cycle_loss(reconstructed_imgs, real_imgs)
            else:
                # Resize if dimensions don't match
                reconstructed_imgs = F.interpolate(
                    reconstructed_imgs, size=real_imgs.shape[2:], mode='bilinear', align_corners=False)
                g_cycle_loss = cycle_loss(reconstructed_imgs, real_imgs)

            # Identity loss
            identity_imgs = generator(real_imgs, real_genres)
            g_identity_loss = identity_loss(identity_imgs, real_imgs)

            g_loss = g_adv_loss + g_genre_loss + 10 * g_cycle_loss + 5 * g_identity_loss
            g_loss.backward()
            g_optimizer.step()

            if i % 50 == 0:
                print(f"[Epoch {epoch}/{EPOCHS}] [Batch {i}/{len(dataloader)}] "
                     f"D Loss: {d_loss.item():.4f} G Loss: {g_loss.item():.4f}")

        # Save checkpoints
        torch.save(generator.state_dict(), f"generator_{epoch}.pth")
        torch.save(discriminator.state_dict(), f"discriminator_{epoch}.pth")



# Audio Conversion Function
def convert_audio(input_path, output_path, source_genre, target_genre, generator, dataset):
    # Load and preprocess audio
    waveform, _ = librosa.load(input_path, sr=SAMPLE_RATE, duration=3)
    if len(waveform) < SAMPLE_RATE * 3:
        waveform = np.pad(waveform, (0, SAMPLE_RATE * 3 - len(waveform)))

    # Convert to mel-spectrogram
    mel_transform = transforms.MelSpectrogram(
        sample_rate=SAMPLE_RATE,
        n_mels=N_MELS,
        n_fft=N_FFT,
        hop_length=HOP_LENGTH
    )
    mel_spec = mel_transform(torch.FloatTensor(waveform))
    mel_spec = torch.log(mel_spec + 1e-9)
    mel_spec = (mel_spec - mel_spec.mean()) / (mel_spec.std() + 1e-9)

    # Convert genre
    generator.eval()
    with torch.no_grad():
        target_idx = dataset.label_dict[target_genre]
        converted_mel = generator(
            mel_spec.unsqueeze(0).unsqueeze(0).to(device),
            torch.tensor([target_idx]).to(device)
        ).squeeze().cpu()

    # Inverse mel-spectrogram
    inv_mel = transforms.InverseMelScale(
        n_stft=N_FFT // 2 + 1,
        n_mels=N_MELS,
        sample_rate=SAMPLE_RATE
    )
    griffin_lim = transforms.GriffinLim(
        n_fft=N_FFT,
        hop_length=HOP_LENGTH,
        n_iter=32
    )

    # Denormalize and convert back to waveform
    converted_mel = converted_mel * mel_spec.std() + mel_spec.mean()
    converted_mel = torch.exp(converted_mel) - 1e-9
    spec_estimate = inv_mel(converted_mel.unsqueeze(0))
    waveform = griffin_lim(spec_estimate)

    # Save result
    torchaudio.save(output_path, waveform, SAMPLE_RATE)

if __name__ == "__main__":
    # Initialize dataset
    dataset = GTZANDataset("/content/gtzan_dataset")
    print("Available genres:", list(dataset.label_dict.keys()))

    # Train or load pretrained models
    train()

    # Example conversion
    generator = GenreConditionedGenerator().to(device)
    generator.load_state_dict(torch.load("generator_99.pth"))

    convert_audio(
        input_path="/content/gtzan_dataset/genres_original/disco/disco.00000.wav",
        output_path="converted_to_blues.wav",
        source_genre="disco",
        target_genre="blues",
        generator=generator,
        dataset=dataset
    )
# Out:
# Available genres: ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
#   1%|          | 1/125 [00:00<01:03,  1.95it/s]
# [Epoch 0/20] [Batch 0/125] D Loss: 3.8324 G Loss: 14.7006
#  41%|████      | 51/125 [00:23<00:39,  1.89it/s]
# [Epoch 0/20] [Batch 50/125] D Loss: 3.4323 G Loss: 9.0255
#  81%|████████  | 101/125 [00:46<00:12,  1.89it/s]
# [Epoch 0/20] [Batch 100/125] D Loss: 3.1408 G Loss: 8.8781
# 100%|██████████| 125/125 [00:56<00:00,  2.20it/s]
#   1%|          | 1/125 [00:00<00:57,  2.16it/s]
# [Epoch 1/20] [Batch 0/125] D Loss: 3.0127 G Loss: 8.8942
#  41%|████      | 51/125 [00:22<00:38,  1.93it/s]
# [Epoch 1/20] [Batch 50/125] D Loss: 2.7789 G Loss: 8.8588
#  81%|████████  | 101/125 [00:45<00:12,  1.91it/s]
# [Epoch 1/20] [Batch 100/125] D Loss: 2.7035 G Loss: 8.9456
# 100%|██████████| 125/125 [00:56<00:00,  2.23it/s]
#   1%|          | 1/125 [00:00<00:57,  2.16it/s]
# [Epoch 2/20] [Batch 0/125] D Loss: 2.5258 G Loss: 9.0807
#  41%|████      | 51/125 [00:23<00:38,  1.91it/s]
# [Epoch 2/20] [Batch 50/125] D Loss: 2.5087 G Loss: 8.8506
#  81%|████████  | 101/125 [00:45<00:12,  1.90it/s]
# [Epoch 2/20] [Batch 100/125] D Loss: 2.4414 G Loss: 8.9830
# 100%|██████████| 125/125 [00:56<00:00,  2.21it/s]
#   1%|          | 1/125 [00:00<00:57,  2.15it/s]
# [Epoch 3/20] [Batch 0/125] D Loss: 2.3388 G Loss: 9.3106
#  41%|████      | 51/125 [00:23<00:39,  1.90it/s]
# [Epoch 3/20] [Batch 50/125] D Loss: 2.3360 G Loss: 9.4505
#  81%|████████  | 101/125 [00:46<00:12,  1.90it/s]
# [Epoch 3/20] [Batch 100/125] D Loss: 2.2172 G Loss: 9.1809
# 100%|██████████| 125/125 [00:56<00:00,  2.20it/s]
#   1%|          | 1/125 [00:00<00:57,  2.14it/s]
# [Epoch 4/20] [Batch 0/125] D Loss: 2.2110 G Loss: 9.6384
#  41%|████      | 51/125 [00:23<00:38,  1.90it/s]
# [Epoch 4/20] [Batch 50/125] D Loss: 2.3223 G Loss: 9.9476
#  81%|████████  | 101/125 [00:46<00:12,  1.90it/s]
# [Epoch 4/20] [Batch 100/125] D Loss: 2.1574 G Loss: 9.5342
# 100%|██████████| 125/125 [00:56<00:00,  2.20it/s]
#   1%|          | 1/125 [00:00<00:57,  2.17it/s]
# [Epoch 5/20] [Batch 0/125] D Loss: 3.0467 G Loss: 7.8818
#  41%|████      | 51/125 [00:23<00:38,  1.90it/s]
# [Epoch 5/20] [Batch 50/125] D Loss: 2.4482 G Loss: 9.2156
#  81%|████████  | 101/125 [00:46<00:12,  1.90it/s]
# [Epoch 5/20] [Batch 100/125] D Loss: 2.2049 G Loss: 9.6237
# 100%|██████████| 125/125 [00:56<00:00,  2.20it/s]
#   1%|          | 1/125 [00:00<00:57,  2.14it/s]
# [Epoch 6/20] [Batch 0/125] D Loss: 2.3153 G Loss: 9.4407
#  41%|████      | 51/125 [00:23<00:39,  1.89it/s]
# [Epoch 6/20] [Batch 50/125] D Loss: 2.3202 G Loss: 9.4172
#  81%|████████  | 101/125 [00:46<00:12,  1.89it/s]
# [Epoch 6/20] [Batch 100/125] D Loss: 2.2289 G Loss: 10.0934
# 100%|██████████| 125/125 [00:56<00:00,  2.20it/s]
#   1%|          | 1/125 [00:00<00:57,  2.17it/s]
# [Epoch 7/20] [Batch 0/125] D Loss: 2.2796 G Loss: 9.7305
#  41%|████      | 51/125 [00:23<00:39,  1.89it/s]
# [Epoch 7/20] [Batch 50/125] D Loss: 2.0537 G Loss: 10.0884
#  81%|████████  | 101/125 [00:46<00:12,  1.89it/s]
# [Epoch 7/20] [Batch 100/125] D Loss: 2.2209 G Loss: 10.0549
# 100%|██████████| 125/125 [00:56<00:00,  2.20it/s]
#   1%|          | 1/125 [00:00<00:57,  2.16it/s]
# [Epoch 8/20] [Batch 0/125] D Loss: 2.1375 G Loss: 9.9265
#  41%|████      | 51/125 [00:23<00:39,  1.90it/s]
# [Epoch 8/20] [Batch 50/125] D Loss: 1.9855 G Loss: 10.0698
#  81%|████████  | 101/125 [00:46<00:12,  1.90it/s]
# [Epoch 8/20] [Batch 100/125] D Loss: 2.1102 G Loss: 9.7423
# 100%|██████████| 125/125 [00:56<00:00,  2.20it/s]
#   1%|          | 1/125 [00:00<00:57,  2.15it/s]
# [Epoch 9/20] [Batch 0/125] D Loss: 2.0131 G Loss: 10.0839
#  41%|████      | 51/125 [00:23<00:38,  1.90it/s]
# [Epoch 9/20] [Batch 50/125] D Loss: 2.1265 G Loss: 9.7423
#  81%|████████  | 101/125 [00:46<00:12,  1.90it/s]
# [Epoch 9/20] [Batch 100/125] D Loss: 2.0831 G Loss: 10.7826
# 100%|██████████| 125/125 [00:56<00:00,  2.20it/s]
#   1%|          | 1/125 [00:00<00:57,  2.17it/s]
# [Epoch 10/20] [Batch 0/125] D Loss: 1.9601 G Loss: 9.3232
#  41%|████      | 51/125 [00:23<00:39,  1.89it/s]
# [Epoch 10/20] [Batch 50/125] D Loss: 2.0587 G Loss: 10.9260
#  81%|████████  | 101/125 [00:46<00:12,  1.89it/s]
# [Epoch 10/20] [Batch 100/125] D Loss: 1.9918 G Loss: 10.1880
# 100%|██████████| 125/125 [00:56<00:00,  2.20it/s]
#   1%|          | 1/125 [00:00<00:57,  2.15it/s]
# [Epoch 11/20] [Batch 0/125] D Loss: 2.1515 G Loss: 10.3195
#  41%|████      | 51/125 [00:23<00:39,  1.90it/s]
# [Epoch 11/20] [Batch 50/125] D Loss: 1.8921 G Loss: 10.9143
#  81%|████████  | 101/125 [00:46<00:12,  1.90it/s]
# [Epoch 11/20] [Batch 100/125] D Loss: 2.0883 G Loss: 10.1897
# 100%|██████████| 125/125 [00:56<00:00,  2.20it/s]
#   1%|          | 1/125 [00:00<00:57,  2.16it/s]
# [Epoch 12/20] [Batch 0/125] D Loss: 1.7190 G Loss: 10.4550
#  41%|████      | 51/125 [00:23<00:38,  1.91it/s]
# [Epoch 12/20] [Batch 50/125] D Loss: 1.7424 G Loss: 10.3497
#  81%|████████  | 101/125 [00:45<00:12,  1.91it/s]
# [Epoch 12/20] [Batch 100/125] D Loss: 2.0183 G Loss: 10.1219
# 100%|██████████| 125/125 [00:56<00:00,  2.21it/s]
#   1%|          | 1/125 [00:00<00:57,  2.15it/s]
# [Epoch 13/20] [Batch 0/125] D Loss: 1.8686 G Loss: 10.6336
#  41%|████      | 51/125 [00:23<00:38,  1.92it/s]
# [Epoch 13/20] [Batch 50/125] D Loss: 1.7766 G Loss: 10.3322
#  81%|████████  | 101/125 [00:45<00:12,  1.92it/s]
# [Epoch 13/20] [Batch 100/125] D Loss: 1.9324 G Loss: 10.5881
# 100%|██████████| 125/125 [00:56<00:00,  2.22it/s]
#   1%|          | 1/125 [00:00<00:56,  2.18it/s]
# [Epoch 14/20] [Batch 0/125] D Loss: 1.8068 G Loss: 10.2749
#  41%|████      | 51/125 [00:23<00:38,  1.91it/s]
# [Epoch 14/20] [Batch 50/125] D Loss: 1.9232 G Loss: 11.1747
#  81%|████████  | 101/125 [00:45<00:12,  1.90it/s]
# [Epoch 14/20] [Batch 100/125] D Loss: 1.7308 G Loss: 10.7394
# 100%|██████████| 125/125 [00:56<00:00,  2.22it/s]
#   1%|          | 1/125 [00:00<00:57,  2.17it/s]
# [Epoch 15/20] [Batch 0/125] D Loss: 1.7208 G Loss: 10.8055
#  41%|████      | 51/125 [00:23<00:38,  1.91it/s]
# [Epoch 15/20] [Batch 50/125] D Loss: 1.8494 G Loss: 10.8477
#  81%|████████  | 101/125 [00:45<00:12,  1.90it/s]
# [Epoch 15/20] [Batch 100/125] D Loss: 1.8771 G Loss: 10.9928
# 100%|██████████| 125/125 [00:56<00:00,  2.21it/s]
#   1%|          | 1/125 [00:00<00:57,  2.15it/s]
# [Epoch 16/20] [Batch 0/125] D Loss: 1.9138 G Loss: 10.4087
#  41%|████      | 51/125 [00:23<00:38,  1.91it/s]
# [Epoch 16/20] [Batch 50/125] D Loss: 1.7891 G Loss: 10.7447
#  81%|████████  | 101/125 [00:46<00:12,  1.90it/s]
# [Epoch 16/20] [Batch 100/125] D Loss: 1.3591 G Loss: 10.1569
# 100%|██████████| 125/125 [00:56<00:00,  2.20it/s]
#   1%|          | 1/125 [00:00<00:57,  2.16it/s]
# [Epoch 17/20] [Batch 0/125] D Loss: 1.7392 G Loss: 10.9263
#  41%|████      | 51/125 [00:23<00:39,  1.89it/s]
# [Epoch 17/20] [Batch 50/125] D Loss: 1.6168 G Loss: 12.0467
#  81%|████████  | 101/125 [00:46<00:12,  1.90it/s]
# [Epoch 17/20] [Batch 100/125] D Loss: 1.6085 G Loss: 10.8518
# 100%|██████████| 125/125 [00:56<00:00,  2.20it/s]
#   1%|          | 1/125 [00:00<00:57,  2.16it/s]
# [Epoch 18/20] [Batch 0/125] D Loss: 1.6396 G Loss: 10.7543
#  41%|████      | 51/125 [00:23<00:39,  1.90it/s]
# [Epoch 18/20] [Batch 50/125] D Loss: 1.5028 G Loss: 10.3606
#  81%|████████  | 101/125 [00:46<00:12,  1.90it/s]
# [Epoch 18/20] [Batch 100/125] D Loss: 1.4991 G Loss: 10.8356
# 100%|██████████| 125/125 [00:56<00:00,  2.20it/s]
#   1%|          | 1/125 [00:00<00:58,  2.13it/s]
# [Epoch 19/20] [Batch 0/125] D Loss: 2.0122 G Loss: 11.1396
#  41%|████      | 51/125 [00:23<00:38,  1.90it/s]
# [Epoch 19/20] [Batch 50/125] D Loss: 1.6557 G Loss: 10.3003
#  81%|████████  | 101/125 [00:46<00:12,  1.90it/s]
# [Epoch 19/20] [Batch 100/125] D Loss: 1.5751 G Loss: 10.8766
# 100%|██████████| 125/125 [00:56<00:00,  2.20it/s]
# <ipython-input-20-1a2d6a3d222c>:382: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   generator.load_state_dict(torch.load("generator_99.pth"))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-1a2d6a3d222c> in <cell line: 372>()
#     380     # Example conversion
#     381     generator = GenreConditionedGenerator().to(device)
# --> 382     generator.load_state_dict(torch.load("generator_99.pth"))
#     383
#     384     convert_audio(
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1317         pickle_load_args["encoding"] = "utf-8"
#    1318
# -> 1319     with _open_file_like(f, "rb") as opened_file:
#    1320         if _is_zipfile(opened_file):
#    1321             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     657 def _open_file_like(name_or_buffer, mode):
#     658     if _is_path(name_or_buffer):
# --> 659         return _open_file(name_or_buffer, mode)
#     660     else:
#     661         if "w" in mode:
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     638 class _open_file(_opener):
#     639     def __init__(self, name, mode):
# --> 640         super().__init__(open(name, mode))
#     641
#     642     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'generator_99.pth'

# %%
generator = GenreConditionedGenerator().to(device)
generator.load_state_dict(torch.load("generator_9.pth"))

convert_audio(
    input_path="/content/gtzan_dataset/genres_original/blues/blues.00000.wav",
    output_path="converted_to_classical.wav",
    source_genre="blues",
    target_genre="classical",
    generator=generator,
    dataset=dataset
)
# Out:
# <ipython-input-23-eeea323c1772>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   generator.load_state_dict(torch.load("generator_9.pth"))

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchaudio
import torchaudio.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import librosa
import numpy as np
import os
from glob import glob
from tqdm import tqdm

# Constants
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SAMPLE_RATE = 22050
N_MELS = 128
N_FFT = 2048
HOP_LENGTH = 512
BATCH_SIZE = 8
EPOCHS = 10
LEARNING_RATE = 2e-4
NUM_GENRES = 10
DURATION = 5  # 5-second clips

# Dataset Class
class GTZANDataset(Dataset):
    def __init__(self, root_dir, duration=DURATION):
        self.file_paths = glob(os.path.join(root_dir, "genres_original", "*", "*.wav"))
        if not self.file_paths:
            raise ValueError(f"No .wav files found in {root_dir}")

        self.labels = [os.path.basename(os.path.dirname(fp)) for fp in self.file_paths]
        self.label_dict = {genre: idx for idx, genre in enumerate(sorted(set(self.labels)))}
        self.duration = duration
        self.time_dim = (duration * SAMPLE_RATE) // HOP_LENGTH + 1

        self.mel_transform = transforms.MelSpectrogram(
            sample_rate=SAMPLE_RATE,
            n_mels=N_MELS,
            n_fft=N_FFT,
            hop_length=HOP_LENGTH
        )

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        file_path = self.file_paths[idx]
        label = self.label_dict[self.labels[idx]]

        waveform, _ = librosa.load(file_path, sr=SAMPLE_RATE, duration=self.duration)
        if len(waveform) < SAMPLE_RATE * self.duration:
            waveform = np.pad(waveform, (0, SAMPLE_RATE * self.duration - len(waveform)), 'constant')

        waveform = torch.FloatTensor(waveform)
        mel_spec = self.mel_transform(waveform)

        # Ensure exact dimensions
        mel_spec = mel_spec[..., :self.time_dim] if mel_spec.shape[-1] > self.time_dim else F.pad(mel_spec, (0, self.time_dim - mel_spec.shape[-1]))

        # Log scaling with clipping
        mel_spec = torch.log(torch.clamp(mel_spec, min=1e-5))
        mel_spec = (mel_spec - mel_spec.mean()) / (mel_spec.std() + 1e-9)

        return mel_spec, label

# Fixed Generator Architecture
class GenreConditionedGenerator(nn.Module):
    def __init__(self, num_genres=NUM_GENRES):
        super().__init__()
        self.genre_embedding = nn.Embedding(num_genres, 128)

        # Initial convolution
        self.initial = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=7, stride=1, padding=3),
            nn.InstanceNorm2d(64),
            nn.LeakyReLU(0.2)
        )

        # Downsample
        self.down1 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(128),
            nn.LeakyReLU(0.2)
        )

        # Residual blocks
        self.resblocks = nn.ModuleList([
            nn.Sequential(
                nn.Conv2d(128, 128, kernel_size=3, padding=1),
                nn.InstanceNorm2d(128),
                nn.LeakyReLU(0.2),
                nn.Conv2d(128, 128, kernel_size=3, padding=1),
                nn.InstanceNorm2d(128)
            ) for _ in range(6)
        ])

        # Genre projection
        self.genre_proj = nn.Linear(128, 128)

        # Upsample
        self.up1 = nn.Sequential(
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, output_padding=0),
            nn.InstanceNorm2d(64),
            nn.ReLU()
        )

        self.up2 = nn.Sequential(
            nn.ConvTranspose2d(64, 1, kernel_size=4, stride=2, padding=1, output_padding=0),
            nn.Tanh()
        )

    def forward(self, x, genre):
        # Store original size
        original_size = x.size()

        # Initial processing
        x = self.initial(x)

        # Downsample
        x = self.down1(x)

        # Add genre conditioning
        genre_emb = self.genre_embedding(genre)
        genre_emb = self.genre_proj(genre_emb)
        genre_emb = genre_emb.view(genre_emb.size(0), genre_emb.size(1), 1, 1)
        genre_emb = genre_emb.expand(-1, -1, x.size(2), x.size(3))
        x = x + genre_emb

        # Residual blocks
        for block in self.resblocks:
            residual = x
            x = block(x) + residual

        # Upsample
        x = self.up1(x)
        x = self.up2(x)

        # Match dimensions
        if x.size() != original_size:
            x = F.interpolate(x, size=original_size[2:], mode='bilinear', align_corners=False)

        return x

# Discriminator
class GenreAwareDiscriminator(nn.Module):
    def __init__(self, num_genres=NUM_GENRES):
        super().__init__()
        self.main = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=4, stride=2, padding=2),
            nn.LeakyReLU(0.2),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=2),
            nn.InstanceNorm2d(128),
            nn.LeakyReLU(0.2),
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=2),
            nn.InstanceNorm2d(256),
            nn.LeakyReLU(0.2),
            nn.AdaptiveAvgPool2d(1)
        )

        self.validity = nn.Linear(256, 1)
        self.genre_classifier = nn.Linear(256, num_genres)

    def forward(self, x):
        features = self.main(x).view(x.size(0), -1)
        return self.validity(features), self.genre_classifier(features)

# Training Function
def train():
    dataset = GTZANDataset("/content/gtzan_dataset")
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

    generator = GenreConditionedGenerator().to(device)
    discriminator = GenreAwareDiscriminator().to(device)

    # Loss functions
    adversarial_loss = nn.BCEWithLogitsLoss()
    genre_loss = nn.CrossEntropyLoss()
    cycle_loss = nn.L1Loss()

    # Optimizers
    g_optimizer = optim.Adam(generator.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))
    d_optimizer = optim.Adam(discriminator.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))

    best_g_loss = float('inf')

    for epoch in range(EPOCHS):
        g_running_loss = 0.0
        d_running_loss = 0.0

        for real, real_genre in tqdm(dataloader):
            real = real.unsqueeze(1).to(device)
            real_genre = real_genre.to(device)

            # Random target genres
            target_genre = torch.randint(0, NUM_GENRES, (real.size(0),)).to(device)

            # Train Discriminator
            d_optimizer.zero_grad()

            fake = generator(real, target_genre)

            # Real loss
            real_validity, real_genre_pred = discriminator(real)
            d_real_loss = adversarial_loss(real_validity, torch.ones_like(real_validity))
            d_real_genre_loss = genre_loss(real_genre_pred, real_genre)

            # Fake loss
            fake_validity, _ = discriminator(fake.detach())
            d_fake_loss = adversarial_loss(fake_validity, torch.zeros_like(fake_validity))

            d_total_loss = d_real_loss + d_fake_loss + d_real_genre_loss
            d_total_loss.backward()
            d_optimizer.step()

            # Train Generator
            g_optimizer.zero_grad()

            fake = generator(real, target_genre)
            reconstructed = generator(fake, real_genre)

            # Adversarial loss
            fake_validity, fake_genre_pred = discriminator(fake)
            g_adv_loss = adversarial_loss(fake_validity, torch.ones_like(fake_validity))

            # Genre classification loss
            g_genre_loss = genre_loss(fake_genre_pred, target_genre)

            # Cycle consistency
            g_cycle_loss = cycle_loss(reconstructed, real)

            g_total_loss = g_adv_loss + g_genre_loss + 10*g_cycle_loss
            g_total_loss.backward()
            g_optimizer.step()

            g_running_loss += g_total_loss.item()
            d_running_loss += d_total_loss.item()

        # Save best model
        if g_running_loss < best_g_loss:
            best_g_loss = g_running_loss
            torch.save(generator.state_dict(), "best_generator.pth")
            torch.save(discriminator.state_dict(), "best_discriminator.pth")

        print(f"Epoch {epoch+1}/{EPOCHS} | G Loss: {g_running_loss/len(dataloader):.4f} | D Loss: {d_running_loss/len(dataloader):.4f}")

# Conversion Function
def convert_audio(input_path, output_path, source_genre, target_genre):
    # Load models
    generator = GenreConditionedGenerator().to(device)
    discriminator = GenreAwareDiscriminator().to(device)
    generator.load_state_dict(torch.load("best_generator.pth"))
    discriminator.load_state_dict(torch.load("best_discriminator.pth"))
    generator.eval()
    discriminator.eval()

    # Load audio
    y, sr = librosa.load(input_path, sr=SAMPLE_RATE, duration=DURATION)
    if len(y) < SAMPLE_RATE * DURATION:
        y = np.pad(y, (0, SAMPLE_RATE * DURATION - len(y)), 'constant')

    # Compute STFT
    stft = librosa.stft(y, n_fft=N_FFT, hop_length=HOP_LENGTH)
    mag = np.abs(stft)
    phase = np.angle(stft)

    # Convert to tensor
    mag = torch.from_numpy(mag).float().unsqueeze(0).unsqueeze(0).to(device)
    mag = torch.log(torch.clamp(mag, min=1e-5))
    mag = (mag - mag.mean()) / (mag.std() + 1e-9)

    # Generate transformed spectrogram
    with torch.no_grad():
        target_idx = dataset.label_dict[target_genre]
        transformed = generator(mag, torch.tensor([target_idx]).to(device))

        # Predict genre
        _, genre_pred = discriminator(transformed)
        predicted_idx = torch.argmax(genre_pred).item()
        predicted_genre = list(dataset.label_dict.keys())[predicted_idx]
        print(f"Predicted genre: {predicted_genre}")

    # Convert back to audio
    transformed = transformed.squeeze().cpu().numpy()
    transformed = np.exp(transformed)

    # Reconstruct with phase
    y_recon = librosa.griffinlim(
        transformed * np.exp(1j * phase),
        n_iter=64,
        hop_length=HOP_LENGTH,
        n_fft=N_FFT
    )

    # Save output
    import soundfile as sf
    sf.write(output_path, y_recon, sr)
    print(f"Converted {source_genre} to {target_genre}. Saved to {output_path}")

if __name__ == "__main__":
    # Initialize dataset
    dataset = GTZANDataset("/content/gtzan_dataset")
    print("Available genres:", list(dataset.label_dict.keys()))

    # Train models
    #train()

    # Example conversion
    convert_audio(
        input_path="/content/gtzan_dataset/genres_original/disco/disco.00003.wav",
        output_path="disco_to_class.wav",
        source_genre="disco",
        target_genre="classical"
    )
# Out:
# Available genres: ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
# Predicted genre: classical
# <ipython-input-9-010c298f27ed>:253: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   generator.load_state_dict(torch.load("best_generator.pth"))
# <ipython-input-9-010c298f27ed>:254: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   discriminator.load_state_dict(torch.load("best_discriminator.pth"))
# Converted disco to classical. Saved to disco_to_class.wav
